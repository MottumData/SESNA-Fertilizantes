# %% [markdown]
# # Data Cleaning Listado de Listado de Beneficiarios 2019

# %% [markdown]
# ## Autores
# - José Luis Delgado Dávara
# - Arturo Ortiz Aguilar
# - Beltrán Valle Gutiérrez-Cortines

# %% [markdown]
# ## Importante leer para entender
#
# En este Notebook se trabaja con 3 listados importantes:
#
# 1. beneficiarios_19 -> Dataset con el listado de TODOS los beneficiarios de 2019.
# 2. Estados_Beneficiarios_2019_2022 -> Dataset sólo con los estados *únicos* encontrados en el dataset anterior.
# 3. Diccionario -> Emparejamiento entre ambos listados de beneficiarios
# 4. Dataset_Inegi -> Catálogo obtenido de Inegi

# %%
import pandas as pd
import seaborn as sns
from thefuzz import fuzz
from thefuzz import process
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
import re
import unidecode

# %%
def clean_text(text):
    """
    De esta manera tenemos el texto sin espacios blancos extra y sobre todo con todas las palabras con capitalización correcta.
    """
    if pd.isna(text):
        return text
    text = text.strip()  # Eliminate white spaces
    text = text.lower()  # Convert to lowercase
    text = unidecode.unidecode(text)  # Remove accents
    text = re.sub('-.*-', '', text) #Remove what is in between - -
    text = re.sub('\s+', ' ', text)  # Eliminate extra white spaces
    text = re.sub('^\s+|\s+?$', '', text)  # Eliminate spaces at the beginning and end
    return text

# %% [markdown]
# # 1. Lectura y limpieza de datos

# %% [markdown]
# ### 1.1 Beneficiarios 2019
#
# Obtenemos el listado único de localidades y listado único de municipios con sus claves.

# %%
beneficiarios_19 = pd.read_csv('../../data/productores_beneficiarios 2019-2022/fertilizantes_2019.csv', encoding='utf-8', skiprows=0)

# %%
beneficiarios_19.shape
# Out:
# (278550, 16)

# %%
beneficiarios_19 = beneficiarios_19[~((beneficiarios_19['ENTIDAD'] == 'NACIONAL') & (beneficiarios_19['MUNICIPIO'] == 'NACIONAL') & (beneficiarios_19['LOCALIDAD'] == 'NACIONAL'))]

# %%
beneficiarios_19.shape
# Out:
# (275026, 16)

# %%
nan_rows = beneficiarios_19[beneficiarios_19.isna().any(axis=1)]

# %%
nan_rows
# Out:
#                                              BENEFICIARIO ZONA ENTIDAD  \
# 278547                                                NaN  NaN     NaN
# 278548                                                NaN  NaN     NaN
# 278549  "Nota: El Sistema de Rendición de Cuentas sobr...  NaN     NaN
#
#        MUNICIPIO LOCALIDAD ESTRATIFICACIÓN PROGRAMA COMPONENTE SUBCOMPONENTE  \
# 278547       NaN       NaN             NaN      NaN        NaN           NaN
# 278548       NaN       NaN             NaN      NaN        NaN           NaN
# 278549       NaN       NaN             NaN      NaN        NaN           NaN
#
#        PRODUCTO FECHA  MONTO FEDERAL APOYO ACTIVIDAD ESLABÓN CICLO AGRÍCOLA
# 278547      NaN   NaN            NaN   NaN       NaN     NaN            NaN
# 278548      NaN   NaN            NaN   NaN       NaN     NaN            NaN
# 278549      NaN   NaN            NaN   NaN       NaN     NaN            NaN

# %%
beneficiarios_19.shape
# Out:
# (275026, 16)

# %%
beneficiarios_19['ENTIDAD'].unique()
# Out:
# array(['GUERRERO', nan], dtype=object)

# %% [markdown]
# Dropeamos los tres valores nulos debido a que las rows enteras salen como nan

# %%
beneficiarios_19.dropna(inplace=True)

# %%
# Obtenemos las localidades únicas en el dataset.
Municipios_19 = beneficiarios_19[['ENTIDAD', 'MUNICIPIO']]
Municipios_19 = Municipios_19.drop_duplicates()

# %%
# Estandarizamos la limpieza de los datos
Municipios_19['ENTIDAD_c_benef'] = Municipios_19['ENTIDAD'].apply(clean_text)
Municipios_19['MUNICIPIO_c_benef'] = Municipios_19['MUNICIPIO'].apply(clean_text)

# %%
# Creamos las dos keys de beneficiarios 
Municipios_19['KEY_benef_mun'] = Municipios_19['ENTIDAD_c_benef'].astype(str) + '-' + Municipios_19[
    'MUNICIPIO_c_benef'].astype(str)

# %%
Municipios_19.shape
# Out:
# (81, 5)

# %%
Municipios_19.columns
# Out:
# Index(['ENTIDAD', 'MUNICIPIO', 'ENTIDAD_c_benef', 'MUNICIPIO_c_benef',
#        'KEY_benef_mun'],
#       dtype='object')

# %% [markdown]
# ### 1.2 INEGI 2019
#
# Obtener listado único de municipios y listado único de localidades de inegi de 2019 con sus claves.

# %%
path_dataset_inegi_2019 = '../../data/inegi/dataset_inegi_clean_2019.csv'
#dataset_inegi_clean = pd.read_csv(path_dataset_inegi_2022, encoding='utf-8', dtype={'CVE_ENT': str, 'CVE_MUN': str, 'CVE_LOC': str})
dataset_inegi_2019 = pd.read_csv(path_dataset_inegi_2019)

# %%
dataset_inegi_2019['CVE_ENT'] = dataset_inegi_2019['CVE_ENT'].astype(str).str.zfill(2)
dataset_inegi_2019['CVE_MUN'] = dataset_inegi_2019['CVE_MUN'].astype(str).str.zfill(3)
dataset_inegi_2019['CVE_LOC'] = dataset_inegi_2019['CVE_LOC'].astype(str).str.zfill(4)

# %%
dataset_inegi_2019
# Out:
#        CVE_ENT   Entidad_inegi CVE_MUN        Municipio_inegi CVE_LOC  \
# 0           01  Aguascalientes     001         Aguascalientes    0001
# 1           01  Aguascalientes     001         Aguascalientes    0094
# 2           01  Aguascalientes     001         Aguascalientes    0096
# 3           01  Aguascalientes     001         Aguascalientes    0100
# 4           01  Aguascalientes     001         Aguascalientes    0102
# ...        ...             ...     ...                    ...     ...
# 299565      32       Zacatecas     058  Santa María de la Paz    0039
# 299566      32       Zacatecas     058  Santa María de la Paz    0040
# 299567      32       Zacatecas     058  Santa María de la Paz    0041
# 299568      32       Zacatecas     058  Santa María de la Paz    0042
# 299569      32       Zacatecas     058  Santa María de la Paz    0043
#
#                Localidad_inegi POB_TOTAL Entidad_c_inegi  \
# 0               Aguascalientes    863893  aguascalientes
# 1               Granja Adelita         5  aguascalientes
# 2                    Agua Azul        41  aguascalientes
# 3                Rancho Alegre         0  aguascalientes
# 4       Los Arbolitos [Rancho]         8  aguascalientes
# ...                        ...       ...             ...
# 299565              San Isidro         1       zacatecas
# 299566                San José         0       zacatecas
# 299567   San Miguel Tepetitlán        97       zacatecas
# 299568              San Rafael         3       zacatecas
# 299569                Santa Fe         0       zacatecas
#
#             Municipio_c_inegi       Localidad_c_inegi
# 0              aguascalientes          aguascalientes
# 1              aguascalientes          granja adelita
# 2              aguascalientes               agua azul
# 3              aguascalientes           rancho alegre
# 4              aguascalientes  los arbolitos [rancho]
# ...                       ...                     ...
# 299565  santa maria de la paz              san isidro
# 299566  santa maria de la paz                san jose
# 299567  santa maria de la paz   san miguel tepetitlan
# 299568  santa maria de la paz              san rafael
# 299569  santa maria de la paz                santa fe
#
# [299570 rows x 10 columns]

# %% [markdown]
# ### 1.2.1 INEGI 2019 Municipios únicos para cada año.

# %%
dataset_inegi_2019['KEY_inegi_municipio'] = dataset_inegi_2019['Entidad_c_inegi'].astype(str) + '-' + dataset_inegi_2019[
    'Municipio_c_inegi'].astype(str) 
dataset_inegi_2019['KEY_inegi_localidad'] = dataset_inegi_2019['Municipio_c_inegi'].astype(str) + '-' + dataset_inegi_2019['Localidad_c_inegi'].astype(str)

# %%
INEGI_UNIQUEMUN_2019 = dataset_inegi_2019.drop(columns=["CVE_LOC", "Localidad_inegi", "Localidad_c_inegi", "KEY_inegi_localidad", "POB_TOTAL"])

INEGI_UNIQUEMUN_2019 = INEGI_UNIQUEMUN_2019.drop_duplicates()

# %%
INEGI_UNIQUEMUN_2019.shape
# Out:
# (2465, 7)

# %%
INEGI_UNIQUEMUN_2019.columns
# Out:
# Index(['CVE_ENT', 'Entidad_inegi', 'CVE_MUN', 'Municipio_inegi',
#        'Entidad_c_inegi', 'Municipio_c_inegi', 'KEY_inegi_municipio'],
#       dtype='object')

# %%
INEGI_UNIQUEMUN_2019.drop_duplicates(subset='KEY_inegi_municipio', keep='first', inplace=True)

# %% [markdown]
# # 2. Diccionario de los datasets de INEGI Y LISTADO BENEFICIARIOS 2019
#
# El objetivo de esta sección es crear dos diccionarios de códigos según BENEFICIARIOS-MUNICIPIOS_INEGI y otro BENEFICIARIOS-LOCALIDADES_INEGI, para cada uno de los estados encontrados en inegi_2019, en este caso el número de keys es menor con lo cual no nos hará falta dividir por estado.
#
# Para ello haremos un Left join entre Localidades_19 y el dataset de INEGI correspondiente.

# %%
# Crear una función para encontrar la mejor coincidencia difusa con límites entre 85 y 100 de coincidencia
def fuzzy_merge_benef2019_2022(df_benef, df_inegi, key1, key2, threshold=85, limit=1):
    """
    df_inegi: DataFrame de la izquierda (el DataFrame principal)
    df_prod: DataFrame de la derecha (el DataFrame con el que se quiere hacer el join)
    key1: Columna de la clave en df_inegi
    key2: Columna de la clave en df_prod
    threshold: Umbral de coincidencia difusa
    limit: Número de coincidencias a encontrar
    """
    s = df_inegi[key2].tolist()
    
    # Encontrar las mejores coincidencias para cada clave en df_inegi
    matches = df_benef[key1].apply(lambda x: process.extractOne(x, s, score_cutoff=threshold))


    # Crear una columna con las mejores coincidencias
    df_benef['best_match'] = [match[0] if match else None for match in matches]
    
    df_benef['match_score'] = [match[1] if match else None for match in matches]
    

    # Hacer el merge con las mejores coincidencias
    df_merged = pd.merge(df_benef, df_inegi, left_on='best_match', right_on=key2, how='left',
                         suffixes=('_benef', '_inegi'))
    
    return df_merged

# %%
diccionario_MUN_19 = fuzzy_merge_benef2019_2022(Municipios_19, INEGI_UNIQUEMUN_2019, 'KEY_benef_mun', 'KEY_inegi_municipio')
diccionario_MUN_19.shape
# Out:
# (81, 14)

# %%
diccionario_MUN_19.drop(columns=['ENTIDAD', 'MUNICIPIO', 'ENTIDAD_c_benef', 'MUNICIPIO_c_benef', 'Entidad_c_inegi',
       'Municipio_c_inegi'], inplace=True)
diccionario_MUN_19.drop_duplicates(subset='KEY_benef_mun', keep='first', inplace=True)

# %%
diccionario_MUN_19.to_csv('../../data/productores_beneficiarios 2019-2022/diccionarios_E3/diccionario_MUN_19.csv', index=False)

# %%
diccionario_MUN_19_simple = pd.read_csv('../../data/productores_beneficiarios 2019-2022/diccionarios_E3/diccionario_MUN_19_simple.csv')

# %% [markdown]
# ### MERGE
#
# Armamos por partes el dataset definitivo:
# 1. Juntamos beneficiarios_19 con el diccionario simple. (listado_beneficiario_parte_I)
# 2. Al df anterior juntamos las claver provenientes del catálogo de Inegi. (listado_beneficiario_parte_II)

# %%
beneficiarios_19.columns
# Out:
# Index(['BENEFICIARIO', 'ZONA', 'ENTIDAD', 'MUNICIPIO', 'LOCALIDAD',
#        'ESTRATIFICACIÓN', 'PROGRAMA', 'COMPONENTE', 'SUBCOMPONENTE',
#        'PRODUCTO', 'FECHA', 'MONTO FEDERAL', 'APOYO', 'ACTIVIDAD', 'ESLABÓN',
#        'CICLO AGRÍCOLA'],
#       dtype='object')

# %%
# Crear una variable KEY en listado de productores y el diccionario para hacer el join

# Clean listado beneficiarios
beneficiarios_19['ESTADO_Clean'] = beneficiarios_19['ENTIDAD'].apply(clean_text)
beneficiarios_19['MUNICIPIO_Clean'] = beneficiarios_19['MUNICIPIO'].apply(clean_text)

# Create KEY in listado beneficiarios
beneficiarios_19['Estado-mun-KEY'] = beneficiarios_19['ESTADO_Clean'].astype(str) + '-' + beneficiarios_19[
    'MUNICIPIO_Clean'].astype(str)

# %%
# Hacer el join de la Parte I
listado_beneficiarios_parte_I = pd.merge(beneficiarios_19, diccionario_MUN_19_simple, left_on="Estado-mun-KEY",
                                        right_on="KEY_benef_mun", how='left', suffixes=('_benef', '_inegi'))

# %%
listado_beneficiarios_parte_I.columns
# Out:
# Index(['BENEFICIARIO', 'ZONA', 'ENTIDAD', 'MUNICIPIO', 'LOCALIDAD',
#        'ESTRATIFICACIÓN', 'PROGRAMA', 'COMPONENTE', 'SUBCOMPONENTE',
#        'PRODUCTO', 'FECHA', 'MONTO FEDERAL', 'APOYO', 'ACTIVIDAD', 'ESLABÓN',
#        'CICLO AGRÍCOLA', 'ESTADO_Clean', 'MUNICIPIO_Clean', 'Estado-mun-KEY',
#        'KEY_benef_mun', 'KEY_inegi_municipio'],
#       dtype='object')

# %%
# Hacer el join de la Parte II
listado_beneficiarios_parte_II = pd.merge(listado_beneficiarios_parte_I, INEGI_UNIQUEMUN_2019, left_on="KEY_inegi_municipio",
                                        right_on="KEY_inegi_municipio", how='left', suffixes=('_benef', '_inegi'))

# %%
listado_beneficiarios_parte_II
# Out:
#                        BENEFICIARIO         ZONA   ENTIDAD         MUNICIPIO  \
# 0            TORRES ROMERO SANTANA   CENTRO PAÍS  GUERRERO             AZOYÚ
# 1           GOMEZ PADILLA DEMETRIA   CENTRO PAÍS  GUERRERO         TECOANAPA
# 2          GUERRERO MELCHOR ADRIAN   CENTRO PAÍS  GUERRERO        TELOLOAPAN
# 3         ROMERO GONZALEZ CELERINA   CENTRO PAÍS  GUERRERO        TELOLOAPAN
# 4            GOMEZ CERON MA.MIREYA   CENTRO PAÍS  GUERRERO         TECOANAPA
# ...                             ...          ...       ...               ...
# 275018     CASTILLO CUEVAS AMANCIO   CENTRO PAÍS  GUERRERO  TAXCO DE ALARCÓN
# 275019    RUEDA SECUNDINO ANACLETO   CENTRO PAÍS  GUERRERO  TAXCO DE ALARCÓN
# 275020       ARMENTA VILLEGAS LUIS   CENTRO PAÍS  GUERRERO            COCULA
# 275021      BELLO JIMENEZ GREGORIA   CENTRO PAÍS  GUERRERO          ATLIXTAC
# 275022  CASIMIRO MARTINEZ ELIBORIA   CENTRO PAÍS  GUERRERO  TAXCO DE ALARCÓN
#
#                        LOCALIDAD ESTRATIFICACIÓN       PROGRAMA  \
# 0                    LOS CHEGÜES            Alto  FERTILIZANTES
# 1                      MECATEPEC            Alto  FERTILIZANTES
# 2       TLAJOCOTLA (LA HACIENDA)            Alto  FERTILIZANTES
# 3                     TELOLOAPAN           Medio  FERTILIZANTES
# 4                     LOS SAUCES            Alto  FERTILIZANTES
# ...                          ...             ...            ...
# 275018                   PAINTLA            Alto  FERTILIZANTES
# 275019                   PAINTLA            Alto  FERTILIZANTES
# 275020                    COCULA            Alto  FERTILIZANTES
# 275021              XALPITZÁHUAC        Muy alto  FERTILIZANTES
# 275022                   PAINTLA            Alto  FERTILIZANTES
#
#            COMPONENTE  SUBCOMPONENTE               PRODUCTO  ...  \
# 0       FERTILIZANTES  FERTILIZANTES  Cultivo de maíz grano  ...
# 1       FERTILIZANTES  FERTILIZANTES  Cultivo de maíz grano  ...
# 2       FERTILIZANTES  FERTILIZANTES  Cultivo de maíz grano  ...
# 3       FERTILIZANTES  FERTILIZANTES  Cultivo de maíz grano  ...
# 4       FERTILIZANTES  FERTILIZANTES  Cultivo de maíz grano  ...
# ...               ...            ...                    ...  ...
# 275018  FERTILIZANTES  FERTILIZANTES  Cultivo de maíz grano  ...
# 275019  FERTILIZANTES  FERTILIZANTES  Cultivo de maíz grano  ...
# 275020  FERTILIZANTES  FERTILIZANTES  Cultivo de maíz grano  ...
# 275021  FERTILIZANTES  FERTILIZANTES  Cultivo de maíz grano  ...
# 275022  FERTILIZANTES  FERTILIZANTES  Cultivo de maíz grano  ...
#
#          MUNICIPIO_Clean             Estado-mun-KEY  \
# 0                  azoyu             guerrero-azoyu
# 1              tecoanapa         guerrero-tecoanapa
# 2             teloloapan        guerrero-teloloapan
# 3             teloloapan        guerrero-teloloapan
# 4              tecoanapa         guerrero-tecoanapa
# ...                  ...                        ...
# 275018  taxco de alarcon  guerrero-taxco de alarcon
# 275019  taxco de alarcon  guerrero-taxco de alarcon
# 275020            cocula            guerrero-cocula
# 275021          atlixtac          guerrero-atlixtac
# 275022  taxco de alarcon  guerrero-taxco de alarcon
#
#                     KEY_benef_mun        KEY_inegi_municipio CVE_ENT  \
# 0                  guerrero-azoyu             guerrero-azoyu      12
# 1              guerrero-tecoanapa         guerrero-tecoanapa      12
# 2             guerrero-teloloapan        guerrero-teloloapan      12
# 3             guerrero-teloloapan        guerrero-teloloapan      12
# 4              guerrero-tecoanapa         guerrero-tecoanapa      12
# ...                           ...                        ...     ...
# 275018  guerrero-taxco de alarcon  guerrero-taxco de alarcon      12
# 275019  guerrero-taxco de alarcon  guerrero-taxco de alarcon      12
# 275020            guerrero-cocula            guerrero-cocula      12
# 275021          guerrero-atlixtac          guerrero-atlixtac      12
# 275022  guerrero-taxco de alarcon  guerrero-taxco de alarcon      12
#
#        Entidad_inegi CVE_MUN   Municipio_inegi Entidad_c_inegi  \
# 0           Guerrero     013             Azoyú        guerrero
# 1           Guerrero     056         Tecoanapa        guerrero
# 2           Guerrero     058        Teloloapan        guerrero
# 3           Guerrero     058        Teloloapan        guerrero
# 4           Guerrero     056         Tecoanapa        guerrero
# ...              ...     ...               ...             ...
# 275018      Guerrero     055  Taxco de Alarcón        guerrero
# 275019      Guerrero     055  Taxco de Alarcón        guerrero
# 275020      Guerrero     017            Cocula        guerrero
# 275021      Guerrero     010          Atlixtac        guerrero
# 275022      Guerrero     055  Taxco de Alarcón        guerrero
#
#        Municipio_c_inegi
# 0                  azoyu
# 1              tecoanapa
# 2             teloloapan
# 3             teloloapan
# 4              tecoanapa
# ...                  ...
# 275018  taxco de alarcon
# 275019  taxco de alarcon
# 275020            cocula
# 275021          atlixtac
# 275022  taxco de alarcon
#
# [275023 rows x 27 columns]

# %%
listado_beneficiarios_parte_II.columns
# Out:
# Index(['BENEFICIARIO', 'ZONA', 'ENTIDAD', 'MUNICIPIO', 'LOCALIDAD',
#        'ESTRATIFICACIÓN', 'PROGRAMA', 'COMPONENTE', 'SUBCOMPONENTE',
#        'PRODUCTO', 'FECHA', 'MONTO FEDERAL', 'APOYO', 'ACTIVIDAD', 'ESLABÓN',
#        'CICLO AGRÍCOLA', 'ESTADO_Clean', 'MUNICIPIO_Clean', 'Estado-mun-KEY',
#        'KEY_benef_mun', 'KEY_inegi_municipio', 'CVE_ENT', 'Entidad_inegi',
#        'CVE_MUN', 'Municipio_inegi', 'Entidad_c_inegi', 'Municipio_c_inegi'],
#       dtype='object')

# %%
listado_beneficiarios_parte_II = listado_beneficiarios_parte_II.drop(columns=['ESTADO_Clean', 'MUNICIPIO_Clean', 'Estado-mun-KEY', 'KEY_inegi_municipio', 'Entidad_c_inegi','Municipio_c_inegi', 'ESTRATIFICACIÓN', 'PROGRAMA', 'COMPONENTE', 'SUBCOMPONENTE', 'APOYO', 'ACTIVIDAD', 'ESLABÓN'])

# %%
listado_beneficiarios_parte_II
# Out:
#                        BENEFICIARIO         ZONA   ENTIDAD         MUNICIPIO  \
# 0            TORRES ROMERO SANTANA   CENTRO PAÍS  GUERRERO             AZOYÚ
# 1           GOMEZ PADILLA DEMETRIA   CENTRO PAÍS  GUERRERO         TECOANAPA
# 2          GUERRERO MELCHOR ADRIAN   CENTRO PAÍS  GUERRERO        TELOLOAPAN
# 3         ROMERO GONZALEZ CELERINA   CENTRO PAÍS  GUERRERO        TELOLOAPAN
# 4            GOMEZ CERON MA.MIREYA   CENTRO PAÍS  GUERRERO         TECOANAPA
# ...                             ...          ...       ...               ...
# 275018     CASTILLO CUEVAS AMANCIO   CENTRO PAÍS  GUERRERO  TAXCO DE ALARCÓN
# 275019    RUEDA SECUNDINO ANACLETO   CENTRO PAÍS  GUERRERO  TAXCO DE ALARCÓN
# 275020       ARMENTA VILLEGAS LUIS   CENTRO PAÍS  GUERRERO            COCULA
# 275021      BELLO JIMENEZ GREGORIA   CENTRO PAÍS  GUERRERO          ATLIXTAC
# 275022  CASIMIRO MARTINEZ ELIBORIA   CENTRO PAÍS  GUERRERO  TAXCO DE ALARCÓN
#
#                        LOCALIDAD               PRODUCTO       FECHA  \
# 0                    LOS CHEGÜES  Cultivo de maíz grano  30/06/2019
# 1                      MECATEPEC  Cultivo de maíz grano  02/07/2019
# 2       TLAJOCOTLA (LA HACIENDA)  Cultivo de maíz grano  27/06/2019
# 3                     TELOLOAPAN  Cultivo de maíz grano  17/07/2019
# 4                     LOS SAUCES  Cultivo de maíz grano  18/07/2019
# ...                          ...                    ...         ...
# 275018                   PAINTLA  Cultivo de maíz grano  27/06/2019
# 275019                   PAINTLA  Cultivo de maíz grano  27/06/2019
# 275020                    COCULA  Cultivo de maíz grano  06/07/2019
# 275021              XALPITZÁHUAC  Cultivo de maíz grano  15/07/2019
# 275022                   PAINTLA  Cultivo de maíz grano  27/06/2019
#
#         MONTO FEDERAL CICLO AGRÍCOLA              KEY_benef_mun CVE_ENT  \
# 0             2430.55         PV2019             guerrero-azoyu      12
# 1             4383.10         PV2019         guerrero-tecoanapa      12
# 2             2430.55         PV2019        guerrero-teloloapan      12
# 3             4383.10         PV2019        guerrero-teloloapan      12
# 4             4383.10         PV2019         guerrero-tecoanapa      12
# ...               ...            ...                        ...     ...
# 275018        2430.55         PV2019  guerrero-taxco de alarcon      12
# 275019        2430.55         PV2019  guerrero-taxco de alarcon      12
# 275020        2430.55         PV2019            guerrero-cocula      12
# 275021        6574.65         PV2019          guerrero-atlixtac      12
# 275022        2430.55         PV2019  guerrero-taxco de alarcon      12
#
#        Entidad_inegi CVE_MUN   Municipio_inegi
# 0           Guerrero     013             Azoyú
# 1           Guerrero     056         Tecoanapa
# 2           Guerrero     058        Teloloapan
# 3           Guerrero     058        Teloloapan
# 4           Guerrero     056         Tecoanapa
# ...              ...     ...               ...
# 275018      Guerrero     055  Taxco de Alarcón
# 275019      Guerrero     055  Taxco de Alarcón
# 275020      Guerrero     017            Cocula
# 275021      Guerrero     010          Atlixtac
# 275022      Guerrero     055  Taxco de Alarcón
#
# [275023 rows x 14 columns]

# %%
listado_beneficiarios_parte_II.columns
# Out:
# Index(['BENEFICIARIO', 'ZONA', 'ENTIDAD', 'MUNICIPIO', 'LOCALIDAD', 'PRODUCTO',
#        'FECHA', 'MONTO FEDERAL', 'CICLO AGRÍCOLA', 'KEY_benef_mun', 'CVE_ENT',
#        'Entidad_inegi', 'CVE_MUN', 'Municipio_inegi'],
#       dtype='object')

# %%
listado_beneficiarios_parte_II.to_csv('../../data/listados_completos/listado_beneficiarios_2019.csv', index=False)

# %%
listado_beneficiarios_parte_II.isna().sum()
# Out:
# BENEFICIARIO       0
# ZONA               0
# ENTIDAD            0
# MUNICIPIO          0
# LOCALIDAD          0
# PRODUCTO           0
# FECHA              0
# MONTO FEDERAL      0
# CICLO AGRÍCOLA     0
# KEY_benef_mun      0
# CVE_ENT            0
# Entidad_inegi      0
# CVE_MUN            0
# Municipio_inegi    0
# dtype: int64

# %% [markdown]
# # 3. Join por entidad (Divide y Vencerás)

# %%
listado_beneficiarios_2019_match = pd.read_csv('../../data/listados_completos/listado_beneficiarios_2019_match.csv')

# %%
listado_beneficiarios_2019_match.shape
# Out:
# (276554, 10)

# %%
listado_beneficiarios_2019_match.columns
# Out:
# Index(['Unnamed: 0', 'BENEFICIARIO', 'ZONA', 'ENTIDAD', 'MUNICIPIO',
#        'LOCALIDAD', 'PRODUCTO', 'FECHA', 'MONTO FEDERAL', 'CICLO AGRÍCOLA'],
#       dtype='object')

# %%
# Obtenemos las localidades únicas en el dataset.
listado_beneficiarios_2019_match = listado_beneficiarios_2019_match.drop(columns=['Unnamed: 0'])

# %%
listado_beneficiarios_2019_match['ENTIDAD_c_benef'] = listado_beneficiarios_2019_match['ENTIDAD'].apply(clean_text)
listado_beneficiarios_2019_match['MUNICIPIO_c_benef'] = listado_beneficiarios_2019_match['MUNICIPIO'].apply(clean_text)
listado_beneficiarios_2019_match['LOCALIDAD_c_benef'] = listado_beneficiarios_2019_match['LOCALIDAD'].apply(clean_text)

# %%
listado_beneficiarios_2019_match['KEY_benef_loc'] = listado_beneficiarios_2019_match['MUNICIPIO_c_benef'].astype(str) + '-' + listado_beneficiarios_2019_match['LOCALIDAD_c_benef'].astype(str)

# %%
listado_beneficiarios_2019_match.shape
# Out:
# (276554, 13)

# %%
listado_beneficiarios_2019_match.ENTIDAD.unique()
# Out:
# array(['Puebla', 'Guerrero', 'México', 'Guanajuato', 'Querétaro',
#        'Zacatecas', 'Veracruz de Ignacio de la Llave', 'Hidalgo',
#        'Michoacán de Ocampo', 'Oaxaca', 'Colima', 'Chiapas', 'Jalisco',
#        'San Luis Potosí', 'Nayarit', 'GUERRERO'], dtype=object)

# %%
listado_beneficiarios_2019_match[listado_beneficiarios_2019_match['LOCALIDAD'] == 'NACIONAL']
# Out:
#                         BENEFICIARIO      ZONA   ENTIDAD  \
# 0        HERNANDEZ MORALES BERNARDO   NACIONAL    Puebla
# 1     GUZMAN VARGAS CELEDONIA JUANA   NACIONAL  Guerrero
# 2          REFUGIO RIVERA VALENTINA   NACIONAL  Guerrero
# 3              LOPEZ GUZMAN AGAPITO   NACIONAL  Guerrero
# 4            SALINAS SALGADO FELIPE   NACIONAL  Guerrero
# ...                              ...       ...       ...
# 1526             DAMASO TOMAS MARIA   NACIONAL  Guerrero
# 1527     HERRERA VILLANUEVA VALENTE   NACIONAL  Guerrero
# 1528           CRUZ NAJERA PERFECTO   NACIONAL  Guerrero
# 1529        CARRILLO VALENTE ISMAEL   NACIONAL  Guerrero
# 1530         BELLO ARIZMENDI MARINO   NACIONAL  Guerrero
#
#                      MUNICIPIO LOCALIDAD               PRODUCTO FECHA  \
# 0     San Sebastián Tlacotepec  NACIONAL  Cultivo de maíz grano  2019
# 1                 Malinaltepec  NACIONAL  Cultivo de maíz grano  2019
# 2                 Malinaltepec  NACIONAL  Cultivo de maíz grano  2019
# 3               Xochistlahuaca  NACIONAL  Cultivo de maíz grano  2019
# 4                   Teloloapan  NACIONAL  Cultivo de maíz grano  2019
# ...                        ...       ...                    ...   ...
# 1526      San Miguel Totolapan  NACIONAL  Cultivo de maíz grano  2019
# 1527      Ayutla de los Libres  NACIONAL  Cultivo de maíz grano  2019
# 1528         Atoyac de Álvarez  NACIONAL  Cultivo de maíz grano  2019
# 1529                 Tecoanapa  NACIONAL  Cultivo de maíz grano  2019
# 1530          Juan R. Escudero  NACIONAL  Cultivo de maíz grano  2019
#
#       MONTO FEDERAL CICLO AGRÍCOLA ENTIDAD_c_benef         MUNICIPIO_c_benef  \
# 0           2191.55         PV2019          puebla  san sebastian tlacotepec
# 1           6813.65         PV2019        guerrero              malinaltepec
# 2           6813.65         PV2019        guerrero              malinaltepec
# 3           4383.10         PV2019        guerrero            xochistlahuaca
# 4           2430.55         PV2019        guerrero                teloloapan
# ...             ...            ...             ...                       ...
# 1526        4622.10         PV2019        guerrero      san miguel totolapan
# 1527        2307.60         PV2019        guerrero      ayutla de los libres
# 1528         239.00         PV2019        guerrero         atoyac de alvarez
# 1529        6574.65         PV2019        guerrero                 tecoanapa
# 1530        4861.10         PV2019        guerrero          juan r. escudero
#
#      LOCALIDAD_c_benef                      KEY_benef_loc
# 0             nacional  san sebastian tlacotepec-nacional
# 1             nacional              malinaltepec-nacional
# 2             nacional              malinaltepec-nacional
# 3             nacional            xochistlahuaca-nacional
# 4             nacional                teloloapan-nacional
# ...                ...                                ...
# 1526          nacional      san miguel totolapan-nacional
# 1527          nacional      ayutla de los libres-nacional
# 1528          nacional         atoyac de alvarez-nacional
# 1529          nacional                 tecoanapa-nacional
# 1530          nacional          juan r. escudero-nacional
#
# [1531 rows x 13 columns]

# %% [markdown]
# ### 3.2.1 Join de localidades - GUERRERO

# %% [markdown]
# Empezamos creando los datasets por entiedad del dataset de beneficiarios.

# %%
entities = [
    'Puebla', 'México', 'Guanajuato', 'Querétaro',
    'Zacatecas', 'Veracruz de Ignacio de la Llave', 'Hidalgo',
    'Michoacán de Ocampo', 'Oaxaca', 'Colima', 'Chiapas',
    'San Luis Potosí', 'Jalisco', 'Nayarit', 'GUERRERO'
]

for entity in entities:
    variable_name = f"Localidades_19_{entity.upper().replace(' ', '_')}"
    dataframe = globals()[variable_name] = listado_beneficiarios_2019_match[listado_beneficiarios_2019_match["ENTIDAD"] == entity]
    dataframe.drop_duplicates(subset='KEY_benef_loc', keep='first', inplace=True)
    print(f"{variable_name}: {dataframe.shape}")
# Out:
# Localidades_19_PUEBLA: (3, 13)
# Localidades_19_MÉXICO: (4, 13)
# Localidades_19_GUANAJUATO: (1, 13)
# Localidades_19_QUERÉTARO: (1, 13)
# Localidades_19_ZACATECAS: (4, 13)
# Localidades_19_VERACRUZ_DE_IGNACIO_DE_LA_LLAVE: (1, 13)
# Localidades_19_HIDALGO: (1, 13)
# Localidades_19_MICHOACÁN_DE_OCAMPO: (1, 13)
# Localidades_19_OAXACA: (5, 13)
# Localidades_19_COLIMA: (1, 13)
# Localidades_19_CHIAPAS: (2, 13)
# Localidades_19_SAN_LUIS_POTOSÍ: (1, 13)
# Localidades_19_JALISCO: (3, 13)
# Localidades_19_NAYARIT: (1, 13)
# Localidades_19_GUERRERO: (4576, 13)
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_87363/1770650823.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop_duplicates(subset='KEY_benef_loc', keep='first', inplace=True)

# %%
Localidades_19_Guerrero = listado_beneficiarios_2019_match[listado_beneficiarios_2019_match['ENTIDAD'] == 'Guerrero']

# %%
Localidades_19_Guerrero.shape
# Out:
# (1499, 13)

# %% [markdown]
# ### 3.2.2 Diccionarios de Inegi por entidad.

# %%
folder_path = '../../data/productores_beneficiarios 2019-2022/diccionarios_E3/2019'

# Listar todos los archivos en la carpeta
files = os.listdir(folder_path)

# Filtrar solo los archivos CSV
csv_files = [file for file in files if file.endswith('.csv')]

# Leer cada archivo CSV y almacenar en variables separadas
for file_name in csv_files:
    file_path = os.path.join(folder_path, file_name)
    # Crear un nombre de variable dinámicamente eliminando la extensión .csv
    var_name = file_name.replace('.csv', '')
    # Leer el archivo CSV y asignar el DataFrame a la variable
    globals()[var_name] = pd.read_csv(file_path)

# Opcional: Imprimir el nombre de las variables creadas y la cantidad de filas y columnas de cada DataFrame
for file_name in csv_files:
    var_name = file_name.replace('.csv', '')
    df = globals()[var_name]
    print(f'{var_name}: {df.shape[0]} filas, {df.shape[1]} columnas')
# Out:
# INEGI_UNIQUELOC_2019_jalisco: 18306 filas, 11 columnas
# INEGI_UNIQUELOC_2019_colima: 2647 filas, 11 columnas
# INEGI_UNIQUELOC_2019_guanajuato: 11130 filas, 11 columnas
# INEGI_UNIQUELOC_2019_nayarit: 4474 filas, 11 columnas
# INEGI_UNIQUELOC_2019_veracruz_de_ignacio_de_la_llave: 25305 filas, 11 columnas
# INEGI_UNIQUELOC_2019_zacatecas: 6418 filas, 11 columnas
# INEGI_UNIQUELOC_2019_michoacán_de_ocampo: 11119 filas, 11 columnas
# INEGI_UNIQUELOC_2019_hidalgo: 5279 filas, 11 columnas
# INEGI_UNIQUELOC_2019_chiapas: 21887 filas, 11 columnas
# INEGI_UNIQUELOC_2019_querétaro: 2829 filas, 11 columnas
# INEGI_UNIQUELOC_2019_méxico: 5217 filas, 11 columnas
# INEGI_UNIQUELOC_2019_oaxaca: 12820 filas, 11 columnas
# INEGI_UNIQUELOC_2019_san_luis_potosí: 8946 filas, 11 columnas
# INEGI_UNIQUELOC_2019_guerrero: 9194 filas, 11 columnas
# INEGI_UNIQUELOC_2019_puebla: 7708 filas, 11 columnas

# %%
INEGI_UNIQUELOC_2019_guerrero.shape
# Out:
# (9194, 11)

# %%
Localidades_19_GUERRERO_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_GUERRERO, INEGI_UNIQUELOC_2019_guerrero, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_GUERRERO_parte_I.shape

Localidades_19_PUEBLA_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_PUEBLA, INEGI_UNIQUELOC_2019_puebla, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_PUEBLA_parte_I.shape

Localidades_19_MEXICO_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_MÉXICO, INEGI_UNIQUELOC_2019_méxico, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_MEXICO_parte_I.shape

Localidades_19_GUANAJUATO_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_GUANAJUATO, INEGI_UNIQUELOC_2019_guanajuato, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_GUANAJUATO_parte_I.shape

Localidades_19_QUERETARO_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_QUERÉTARO, INEGI_UNIQUELOC_2019_querétaro, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_QUERETARO_parte_I.shape

Localidades_19_ZACATECAS_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_ZACATECAS, INEGI_UNIQUELOC_2019_zacatecas, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_ZACATECAS_parte_I.shape

Localidades_19_VERACRUZ_DE_IGNACIO_DE_LA_LLAVE_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_VERACRUZ_DE_IGNACIO_DE_LA_LLAVE, INEGI_UNIQUELOC_2019_veracruz_de_ignacio_de_la_llave, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_VERACRUZ_DE_IGNACIO_DE_LA_LLAVE_parte_I.shape

Localidades_19_HIDALGO_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_HIDALGO, INEGI_UNIQUELOC_2019_hidalgo, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_HIDALGO_parte_I.shape

Localidades_19_MICHOACAN_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_MICHOACÁN_DE_OCAMPO, INEGI_UNIQUELOC_2019_michoacán_de_ocampo, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_MICHOACAN_parte_I.shape

Localidades_19_OAXACA_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_OAXACA, INEGI_UNIQUELOC_2019_oaxaca, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_OAXACA_parte_I.shape

Localidades_19_COLIMA_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_COLIMA, INEGI_UNIQUELOC_2019_colima, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_COLIMA_parte_I.shape

Localidades_19_CHIAPAS_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_CHIAPAS, INEGI_UNIQUELOC_2019_chiapas, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_CHIAPAS_parte_I.shape

Localidades_19_POTOSI_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_SAN_LUIS_POTOSÍ, INEGI_UNIQUELOC_2019_san_luis_potosí, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_POTOSI_parte_I.shape

Localidades_19_JALISCO_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_JALISCO, INEGI_UNIQUELOC_2019_jalisco, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_JALISCO_parte_I.shape

Localidades_19_NAYARIT_parte_I = fuzzy_merge_benef2019_2022(Localidades_19_NAYARIT, INEGI_UNIQUELOC_2019_nayarit, 'KEY_benef_loc', 'KEY_inegi_localidad')
Localidades_19_NAYARIT_parte_I.shape

# %%
# Concatenate datasets vertically
diccionario_LOC_19 = pd.concat([
    Localidades_19_GUERRERO_parte_I,
    Localidades_19_PUEBLA_parte_I,
    Localidades_19_MEXICO_parte_I,
    Localidades_19_GUANAJUATO_parte_I,
    Localidades_19_QUERETARO_parte_I,
    Localidades_19_ZACATECAS_parte_I,
    Localidades_19_VERACRUZ_DE_IGNACIO_DE_LA_LLAVE_parte_I,
    Localidades_19_HIDALGO_parte_I,
    Localidades_19_MICHOACAN_parte_I,
    Localidades_19_OAXACA_parte_I,
    Localidades_19_COLIMA_parte_I,
    Localidades_19_CHIAPAS_parte_I,
    Localidades_19_POTOSI_parte_I,
    Localidades_19_JALISCO_parte_I,
    Localidades_19_NAYARIT_parte_I
], axis=0)

# Check the shape of the concatenated DataFrame
diccionario_LOC_19.shape

# %%
diccionario_LOC_19.drop(columns=['BENEFICIARIO', 'ZONA', 'ENTIDAD', 'MUNICIPIO', 'LOCALIDAD', 'PRODUCTO',
       'FECHA', 'MONTO FEDERAL', 'CICLO AGRÍCOLA', 'ENTIDAD_c_benef',
       'MUNICIPIO_c_benef', 'LOCALIDAD_c_benef', 'best_match', 'CVE_ENT', 'Entidad_inegi', 'CVE_MUN', 'Municipio_inegi',
       'CVE_LOC', 'Localidad_inegi', 'POB_TOTAL', 'Entidad_c_inegi',
       'Municipio_c_inegi', 'Localidad_c_inegi'], inplace=True)

# %%
diccionario_LOC_19.to_csv('../../data/productores_beneficiarios 2019-2022/diccionarios_E3/diccionario_LOC_19.csv', index=False)

# %%
diccionario_LOC_19.isna().sum()

# %% [markdown]
# # 4. Diccionarios de localidades y merge respectivos.

# %% [markdown]
# Empezamos leyendo el diccionario_LOC_20_simple, el cual solo tiene key_benef_mun y key_inegi_municipio manipulada.

# %%
import pandas as pd

# Intentar leer el archivo CSV con diferentes configuraciones de lectura
try:
    diccionario_LOC_19_simple = pd.read_csv('../../data/productores_beneficiarios 2019-2022/diccionarios_E3/diccionario_LOC_19_simple.csv', encoding='cp1252', 
                          delimiter=';')
    #diccionario_LOC_21_simple.drop(columns=['ValidaciÃ³n', 'Propuesta'], inplace=True)
    print(diccionario_LOC_19_simple.head())
except pd.errors.ParserError as e:
    print("Error al leer el archivo CSV:", e)
# Out:
#                                     ï»¿KEY_benef_loc  match_score  \
# 0  teloloapan-cuadrilla del encanto (cerro del ba...         86.0
# 1               arcelia-colonia emperador cuauhtemoc         86.0
# 2  arcelia-reforma de lazaro cardenas (el aterriz...         86.0
# 3                 marquelia-huerta luciano bonifacio         86.0
# 4  atoyac de alvarez-colonia benito juarez (el po...         86.0
#
#                    KEY_inegi_localidad
# 0                teloloapan-teloloapan
# 1                      arcelia-arcelia
# 2                      arcelia-arcelia
# 3                  marquelia-marquelia
# 4  atoyac de alvarez-atoyac de alvarez

# %%
diccionario_LOC_19_simple.columns
# Out:
# Index(['ï»¿KEY_benef_loc', 'match_score', 'KEY_inegi_localidad'], dtype='object')

# %%
diccionario_LOC_19_simple.rename(columns={'ï»¿KEY_benef_loc': 'KEY_benef_loc'}, inplace=True)

# %%
diccionario_LOC_19_simple.columns
# Out:
# Index(['KEY_benef_loc', 'match_score', 'KEY_inegi_localidad'], dtype='object')

# %%
diccionario_LOC_19_simple
# Out:
#                                           KEY_benef_loc  match_score  \
# 0     teloloapan-cuadrilla del encanto (cerro del ba...         86.0
# 1                  arcelia-colonia emperador cuauhtemoc         86.0
# 2     arcelia-reforma de lazaro cardenas (el aterriz...         86.0
# 3                    marquelia-huerta luciano bonifacio         86.0
# 4     atoyac de alvarez-colonia benito juarez (el po...         86.0
# ...                                                 ...          ...
# 4673                                                NaN          NaN
# 4674                                                NaN          NaN
# 4675                                                NaN          NaN
# 4676                                                NaN          NaN
# 4677                                                NaN          NaN
#
#                       KEY_inegi_localidad
# 0                   teloloapan-teloloapan
# 1                         arcelia-arcelia
# 2                         arcelia-arcelia
# 3                     marquelia-marquelia
# 4     atoyac de alvarez-atoyac de alvarez
# ...                                   ...
# 4673                                  NaN
# 4674                                  NaN
# 4675                                  NaN
# 4676                                  NaN
# 4677                                  NaN
#
# [4678 rows x 3 columns]

# %%
listado_beneficiarios_2019_match.columns
# Out:
# Index(['BENEFICIARIO', 'ZONA', 'ENTIDAD', 'MUNICIPIO', 'LOCALIDAD', 'PRODUCTO',
#        'FECHA', 'MONTO FEDERAL', 'CICLO AGRÍCOLA', 'ENTIDAD_c_benef',
#        'MUNICIPIO_c_benef', 'LOCALIDAD_c_benef', 'KEY_benef_loc'],
#       dtype='object')

# %%
listado_beneficiarios_2019_match['MUNICIPIO_Clean'] = listado_beneficiarios_2019_match['MUNICIPIO'].apply(clean_text)
listado_beneficiarios_2019_match['LOCALIDAD_Clean'] = listado_beneficiarios_2019_match['LOCALIDAD'].apply(clean_text)

# Create KEY in listado beneficiarios
listado_beneficiarios_2019_match['Municipio-loc-KEY'] = listado_beneficiarios_2019_match['MUNICIPIO_Clean'].astype(str) + '-' + listado_beneficiarios_2019_match[
    'LOCALIDAD_Clean'].astype(str)

# %% [markdown]
# Primer merge entre listado_beneficiarios_parte_II, y diccionario_LOC_22_simple. En este merge cogemos el dataset con los municipios corregidos previamente y ejecutamos el merge de manera que nos traemos las key_inegi_localidad corregidas.

# %%
listado_beneficiarios_2019_match.shape
# Out:
# (276554, 16)

# %%
INEGI_UNIQUELOC_2019 = dataset_inegi_2019.drop(columns=['Entidad_c_inegi', 'Municipio_c_inegi',
       'Localidad_c_inegi', 'POB_TOTAL'])
INEGI_UNIQUELOC_2019 = INEGI_UNIQUELOC_2019.drop_duplicates(subset='KEY_inegi_localidad', keep='first')

# %%
INEGI_UNIQUELOC_2019.columns
# Out:
# Index(['CVE_ENT', 'Entidad_inegi', 'CVE_MUN', 'Municipio_inegi', 'CVE_LOC',
#        'Localidad_inegi', 'KEY_inegi_municipio', 'KEY_inegi_localidad'],
#       dtype='object')

# %%
INEGI_UNIQUELOC_2019
# Out:
#        CVE_ENT   Entidad_inegi CVE_MUN        Municipio_inegi CVE_LOC  \
# 0           01  Aguascalientes     001         Aguascalientes    0001
# 1           01  Aguascalientes     001         Aguascalientes    0094
# 2           01  Aguascalientes     001         Aguascalientes    0096
# 3           01  Aguascalientes     001         Aguascalientes    0100
# 4           01  Aguascalientes     001         Aguascalientes    0102
# ...        ...             ...     ...                    ...     ...
# 299565      32       Zacatecas     058  Santa María de la Paz    0039
# 299566      32       Zacatecas     058  Santa María de la Paz    0040
# 299567      32       Zacatecas     058  Santa María de la Paz    0041
# 299568      32       Zacatecas     058  Santa María de la Paz    0042
# 299569      32       Zacatecas     058  Santa María de la Paz    0043
#
#                Localidad_inegi              KEY_inegi_municipio  \
# 0               Aguascalientes    aguascalientes-aguascalientes
# 1               Granja Adelita    aguascalientes-aguascalientes
# 2                    Agua Azul    aguascalientes-aguascalientes
# 3                Rancho Alegre    aguascalientes-aguascalientes
# 4       Los Arbolitos [Rancho]    aguascalientes-aguascalientes
# ...                        ...                              ...
# 299565              San Isidro  zacatecas-santa maria de la paz
# 299566                San José  zacatecas-santa maria de la paz
# 299567   San Miguel Tepetitlán  zacatecas-santa maria de la paz
# 299568              San Rafael  zacatecas-santa maria de la paz
# 299569                Santa Fe  zacatecas-santa maria de la paz
#
#                                 KEY_inegi_localidad
# 0                     aguascalientes-aguascalientes
# 1                     aguascalientes-granja adelita
# 2                          aguascalientes-agua azul
# 3                      aguascalientes-rancho alegre
# 4             aguascalientes-los arbolitos [rancho]
# ...                                             ...
# 299565             santa maria de la paz-san isidro
# 299566               santa maria de la paz-san jose
# 299567  santa maria de la paz-san miguel tepetitlan
# 299568             santa maria de la paz-san rafael
# 299569               santa maria de la paz-santa fe
#
# [271098 rows x 8 columns]

# %%
# Marcar todos los duplicados en las columnas 'columna1' y 'columna2' como True
duplicados = listado_beneficiarios_2019_match.duplicated()

# Filtrar el DataFrame original para mostrar solo los duplicados
df_duplicados = listado_beneficiarios_2019_match[duplicados]

# %%
df_duplicados
# Out:
#                           BENEFICIARIO         ZONA   ENTIDAD  \
# 43112        BETANCOURT APAEZ ANTONIO   CENTRO PAÍS  GUERRERO
# 47378       DE LA CRUZ PABLO SALVADOR   CENTRO PAÍS  GUERRERO
# 52711        FERNANDEZ ALVAREZ ISABEL   CENTRO PAÍS  GUERRERO
# 72145                VILLA DIMAS JOSE   CENTRO PAÍS  GUERRERO
# 72232      URIOSTEGUI FERNANDEZ MARIA   CENTRO PAÍS  GUERRERO
# 75583          DURAN GARCIA ALEJANDRO   CENTRO PAÍS  GUERRERO
# 86238           MAURICIO LOPEZ GERMAN   CENTRO PAÍS  GUERRERO
# 95993             CASIMIRO PARRA RAUL   CENTRO PAÍS  GUERRERO
# 96689       RIVERA DE LA CRUZ DELFINO   CENTRO PAÍS  GUERRERO
# 100867    PRUDENCIO RAMIREZ MARGARITO   CENTRO PAÍS  GUERRERO
# 102479         DIRCIO AGUILAR PLACIDO   CENTRO PAÍS  GUERRERO
# 107838       SALGADO RODRIGUEZ EFRAIN   CENTRO PAÍS  GUERRERO
# 107946        FRANCISCO SANTOS SANTOS   CENTRO PAÍS  GUERRERO
# 111030           GOMEZ ADAME APOLINAR   CENTRO PAÍS  GUERRERO
# 118507         TOLEDO RODRIGUEZ JESUS   CENTRO PAÍS  GUERRERO
# 118997           ORTIZ OCAMPO ALBERTO   CENTRO PAÍS  GUERRERO
# 121404            FLORES FLORES OCIEL   CENTRO PAÍS  GUERRERO
# 127061            OLLUA NIÑO J CARMEN   CENTRO PAÍS  GUERRERO
# 138943          DEGANTE ENRIQUEZ TITO   CENTRO PAÍS  GUERRERO
# 139710    CORONEL HERNANDEZ CELESTINO   CENTRO PAÍS  GUERRERO
# 144478        MARTINEZ DIAZ FRANCISCO   CENTRO PAÍS  GUERRERO
# 146918  HERNANDEZ HERNANDEZ GAUDENCIA   CENTRO PAÍS  GUERRERO
# 149044              ROMAN MIRANDA NOE   CENTRO PAÍS  GUERRERO
# 153728         ROSAS HERNANDEZ ANDRES   CENTRO PAÍS  GUERRERO
# 163527          BELLO RAMIREZ NESTORA   CENTRO PAÍS  GUERRERO
# 177186               ROQUE SIMON JUAN   CENTRO PAÍS  GUERRERO
# 182894          MORALES MILLAN RUFINA   CENTRO PAÍS  GUERRERO
# 186704       CALVARIO RAMIREZ MATILDE   CENTRO PAÍS  GUERRERO
# 187303            FLORES MARINO MARIA   CENTRO PAÍS  GUERRERO
# 190290       JAIMES BENITEZ FRANCISCO   CENTRO PAÍS  GUERRERO
# 191216             MONICO MILLAN JOSE   CENTRO PAÍS  GUERRERO
# 195509    GALEANA LORENZO JULIO CESAR   CENTRO PAÍS  GUERRERO
# 198631       HERNANDEZ DIRCIO ALFREDA   CENTRO PAÍS  GUERRERO
# 201827            VARGAS CRUZ ANTONIA   CENTRO PAÍS  GUERRERO
# 205443            APARICIO CRUZ PEDRO   CENTRO PAÍS  GUERRERO
# 205605         ARMENTA LAGUNAS SANTOS   CENTRO PAÍS  GUERRERO
# 207576            MORALES MILLAN JOSE   CENTRO PAÍS  GUERRERO
# 218826           ALMAZAN CEDILLO JUAN   CENTRO PAÍS  GUERRERO
# 229834             SANCHEZ VALLE ROSA   CENTRO PAÍS  GUERRERO
# 232556             LAGUNAS ALDAY LUIS   CENTRO PAÍS  GUERRERO
# 234234         URIOSTEGUI ROMAN PEDRO   CENTRO PAÍS  GUERRERO
# 236356    SANTIAGO CONCEPCION ALBERTO   CENTRO PAÍS  GUERRERO
# 246638         ARMENTA LAGUNAS SANTOS   CENTRO PAÍS  GUERRERO
# 253778             CORTES VARGAS JOSE   CENTRO PAÍS  GUERRERO
# 256615        PINZON GARCIA FRANCISCO   CENTRO PAÍS  GUERRERO
# 266709       TOLENTINO MILLAN LUCIANO   CENTRO PAÍS  GUERRERO
# 268075            MONICO JUAREZ MARIO   CENTRO PAÍS  GUERRERO
# 270992      DELGADO GONZALEZ LEONARDA   CENTRO PAÍS  GUERRERO
#
#                          MUNICIPIO  \
# 43112     HUITZUCO DE LOS FIGUEROA
# 47378           TLAPA DE COMONFORT
# 52711                   TELOLOAPAN
# 72145               LEONARDO BRAVO
# 72232                   TELOLOAPAN
# 75583                      TETIPAC
# 86238          CUTZAMALA DE PINZÓN
# 95993                     ATLIXTAC
# 96689            ZAPOTITLÁN TABLAS
# 100867                   TECOANAPA
# 102479           ZAPOTITLÁN TABLAS
# 107838                  TELOLOAPAN
# 107946          CHILAPA DE ÁLVAREZ
# 111030  GENERAL HELIODORO CASTILLO
# 118507    HUITZUCO DE LOS FIGUEROA
# 118997                  TELOLOAPAN
# 121404  GENERAL HELIODORO CASTILLO
# 127061            JUAN R. ESCUDERO
# 138943                  TELOLOAPAN
# 139710                     OLINALÁ
# 144478                  METLATÓNOC
# 146918                   TECOANAPA
# 149044                  TELOLOAPAN
# 153728                     PILCAYA
# 163527                   TECOANAPA
# 177186                   TECOANAPA
# 182894   CHILPANCINGO DE LOS BRAVO
# 186704          CHILAPA DE ÁLVAREZ
# 187303  GENERAL HELIODORO CASTILLO
# 190290                  TLAPEHUALA
# 191216   CHILPANCINGO DE LOS BRAVO
# 195509                  SAN MARCOS
# 198631     JOSÉ JOAQUÍN DE HERRERA
# 201827                   TECOANAPA
# 205443                   TECOANAPA
# 205605                  TELOLOAPAN
# 207576   CHILPANCINGO DE LOS BRAVO
# 218826                HUAMUXTITLÁN
# 229834                    ATLIXTAC
# 232556                     APAXTLA
# 234234                  TELOLOAPAN
# 236356              XOCHISTLAHUACA
# 246638                  TELOLOAPAN
# 253778                    ATLIXTAC
# 256615                  METLATÓNOC
# 266709   CHILPANCINGO DE LOS BRAVO
# 268075   CHILPANCINGO DE LOS BRAVO
# 270992                     APAXTLA
#
#                                               LOCALIDAD  \
# 43112                                        LAGUNILLAS
# 47378                                       CHIEPETEPEC
# 52711                                        CERRO ALTO
# 72145                           COATEPEC DE LA ESCALERA
# 72232                                        CERRO ALTO
# 75583                                    CHONTALCOATLÁN
# 86238                                  TLANEXPA (NEXPA)
# 95993             HUITZAPULA (SAN PEDRO HUITZAPULA SUR)
# 96689                                       SAN AGUSTÍN
# 100867                                     LOS SAUCITOS
# 102479                              ESCALERILLA LAGUNAS
# 107838                                       TELOLOAPAN
# 107946                                         PAPAXTLA
# 111030                                         IZOTEPEC
# 118507                                       QUETZALAPA
# 118997                      EL AHUACATITO (EL AGUACATE)
# 121404                                     LA PRIMAVERA
# 127061  SAN JUAN DEL REPARO NORTE (SAN JUAN DEL REPARO)
# 138943                              HUERTA GRANDE NORTE
# 139710                                          OLINALÁ
# 144478           COCUILOTLAZALA (COCUITLAZALA EL VIEJO)
# 146918                                 LA PERSEVERANCIA
# 149044                                       OXTOTITLÁN
# 153728                                     CACAHUAMILPA
# 163527                                     LOS SAUCITOS
# 177186                                       HUAMUCHAPA
# 182894                                      SAN VICENTE
# 186704                                      ATZACOALOYA
# 187303                                     LA PRIMAVERA
# 190290                       SAN ANTONIO DE LAS HUERTAS
# 191216                                      SAN VICENTE
# 195509                                    SANTO DOMINGO
# 198631                                 AJACAYÁN ORIENTE
# 201827                         EL TECHALE (TLALTECHALE)
# 205443                                     XALPATLÁHUAC
# 205605                                        TEHUIXTLA
# 207576                                      SAN VICENTE
# 218826                              SAN MIGUEL TOTOLAPA
# 229834                                         OCOPEXCO
# 232556                      CIUDAD APAXTLA DE CASTREJÓN
# 234234                                       TELOLOAPAN
# 236356                                ARROYO TOTOLE UNO
# 246638                                        TEHUIXTLA
# 253778                                         ATLIXTAC
# 256615                                      BUENA VISTA
# 266709                                      EL AGUAJITO
# 268075                                      SAN VICENTE
# 270992                      CIUDAD APAXTLA DE CASTREJÓN
#
#                      PRODUCTO       FECHA  MONTO FEDERAL CICLO AGRÍCOLA  \
# 43112   Cultivo de maíz grano  13/06/2019        7291.65         PV2019
# 47378   Cultivo de maíz grano  21/06/2019        2430.55         PV2019
# 52711   Cultivo de maíz grano  05/07/2019        4622.10         PV2019
# 72145   Cultivo de maíz grano  22/06/2019        6813.65         PV2019
# 72232   Cultivo de maíz grano  05/07/2019        4383.10         PV2019
# 75583   Cultivo de maíz grano  25/06/2019        2430.55         PV2019
# 86238   Cultivo de maíz grano  26/07/2019        4622.10         PV2019
# 95993   Cultivo de maíz grano  23/07/2019        6574.65         PV2019
# 96689   Cultivo de maíz grano  10/07/2019        6813.65         PV2019
# 100867  Cultivo de maíz grano  16/07/2019        4383.10         PV2019
# 102479  Cultivo de maíz grano  11/07/2019        6813.65         PV2019
# 107838  Cultivo de maíz grano  28/07/2019        4383.10         PV2019
# 107946  Cultivo de maíz grano  09/07/2019        2430.55         PV2019
# 111030  Cultivo de maíz grano  10/07/2019        4622.10         PV2019
# 118507  Cultivo de maíz grano  28/06/2019        4622.10         PV2019
# 118997  Cultivo de maíz grano  25/06/2019        4622.10         PV2019
# 121404  Cultivo de maíz grano  24/06/2019        4209.55         PV2019
# 127061  Cultivo de maíz grano  29/06/2019        2430.55         PV2019
# 138943  Cultivo de maíz grano  03/07/2019        4622.10         PV2019
# 139710  Cultivo de maíz grano  15/07/2019        4622.10         PV2019
# 144478  Cultivo de maíz grano  07/08/2019        1186.00         PV2019
# 146918  Cultivo de maíz grano  08/06/2019        2191.55         PV2019
# 149044  Cultivo de maíz grano  31/07/2019        4383.10         PV2019
# 153728  Cultivo de maíz grano  22/06/2019        2430.55         PV2019
# 163527  Cultivo de maíz grano  18/06/2019        4383.10         PV2019
# 177186  Cultivo de maíz grano  16/07/2019        4383.10         PV2019
# 182894  Cultivo de maíz grano  28/06/2019        4622.10         PV2019
# 186704  Cultivo de maíz grano  15/07/2019        2430.55         PV2019
# 187303  Cultivo de maíz grano  24/06/2019        4209.55         PV2019
# 190290  Cultivo de maíz grano  27/06/2019        4622.10         PV2019
# 191216  Cultivo de maíz grano  27/06/2019        4622.10         PV2019
# 195509  Cultivo de maíz grano  31/07/2019        2011.10         PV2019
# 198631  Cultivo de maíz grano  29/06/2019        2430.55         PV2019
# 201827  Cultivo de maíz grano  16/07/2019        4383.10         PV2019
# 205443  Cultivo de maíz grano  14/06/2019        4383.10         PV2019
# 205605  Cultivo de maíz grano  22/07/2019        4383.10         PV2019
# 207576  Cultivo de maíz grano  27/06/2019        4622.10         PV2019
# 218826  Cultivo de maíz grano  12/06/2019        2430.55         PV2019
# 229834  Cultivo de maíz grano  11/07/2019        4383.10         PV2019
# 232556  Cultivo de maíz grano  06/07/2019        4622.10         PV2019
# 234234  Cultivo de maíz grano  15/07/2019        4622.10         PV2019
# 236356  Cultivo de maíz grano  11/07/2019        2430.55         PV2019
# 246638  Cultivo de maíz grano  22/07/2019        4383.10         PV2019
# 253778  Cultivo de maíz grano  15/07/2019        6813.65         PV2019
# 256615  Cultivo de maíz grano  13/07/2019        2430.55         PV2019
# 266709  Cultivo de maíz grano  09/07/2019        4622.10         PV2019
# 268075  Cultivo de maíz grano  28/06/2019        2430.55         PV2019
# 270992  Cultivo de maíz grano  19/07/2019        4622.10         PV2019
#
#        ENTIDAD_c_benef           MUNICIPIO_c_benef  \
# 43112         guerrero    huitzuco de los figueroa
# 47378         guerrero          tlapa de comonfort
# 52711         guerrero                  teloloapan
# 72145         guerrero              leonardo bravo
# 72232         guerrero                  teloloapan
# 75583         guerrero                     tetipac
# 86238         guerrero         cutzamala de pinzon
# 95993         guerrero                    atlixtac
# 96689         guerrero           zapotitlan tablas
# 100867        guerrero                   tecoanapa
# 102479        guerrero           zapotitlan tablas
# 107838        guerrero                  teloloapan
# 107946        guerrero          chilapa de alvarez
# 111030        guerrero  general heliodoro castillo
# 118507        guerrero    huitzuco de los figueroa
# 118997        guerrero                  teloloapan
# 121404        guerrero  general heliodoro castillo
# 127061        guerrero            juan r. escudero
# 138943        guerrero                  teloloapan
# 139710        guerrero                     olinala
# 144478        guerrero                  metlatonoc
# 146918        guerrero                   tecoanapa
# 149044        guerrero                  teloloapan
# 153728        guerrero                     pilcaya
# 163527        guerrero                   tecoanapa
# 177186        guerrero                   tecoanapa
# 182894        guerrero   chilpancingo de los bravo
# 186704        guerrero          chilapa de alvarez
# 187303        guerrero  general heliodoro castillo
# 190290        guerrero                  tlapehuala
# 191216        guerrero   chilpancingo de los bravo
# 195509        guerrero                  san marcos
# 198631        guerrero     jose joaquin de herrera
# 201827        guerrero                   tecoanapa
# 205443        guerrero                   tecoanapa
# 205605        guerrero                  teloloapan
# 207576        guerrero   chilpancingo de los bravo
# 218826        guerrero                huamuxtitlan
# 229834        guerrero                    atlixtac
# 232556        guerrero                     apaxtla
# 234234        guerrero                  teloloapan
# 236356        guerrero              xochistlahuaca
# 246638        guerrero                  teloloapan
# 253778        guerrero                    atlixtac
# 256615        guerrero                  metlatonoc
# 266709        guerrero   chilpancingo de los bravo
# 268075        guerrero   chilpancingo de los bravo
# 270992        guerrero                     apaxtla
#
#                                       LOCALIDAD_c_benef  \
# 43112                                        lagunillas
# 47378                                       chiepetepec
# 52711                                        cerro alto
# 72145                           coatepec de la escalera
# 72232                                        cerro alto
# 75583                                    chontalcoatlan
# 86238                                  tlanexpa (nexpa)
# 95993             huitzapula (san pedro huitzapula sur)
# 96689                                       san agustin
# 100867                                     los saucitos
# 102479                              escalerilla lagunas
# 107838                                       teloloapan
# 107946                                         papaxtla
# 111030                                         izotepec
# 118507                                       quetzalapa
# 118997                      el ahuacatito (el aguacate)
# 121404                                     la primavera
# 127061  san juan del reparo norte (san juan del reparo)
# 138943                              huerta grande norte
# 139710                                          olinala
# 144478           cocuilotlazala (cocuitlazala el viejo)
# 146918                                 la perseverancia
# 149044                                       oxtotitlan
# 153728                                     cacahuamilpa
# 163527                                     los saucitos
# 177186                                       huamuchapa
# 182894                                      san vicente
# 186704                                      atzacoaloya
# 187303                                     la primavera
# 190290                       san antonio de las huertas
# 191216                                      san vicente
# 195509                                    santo domingo
# 198631                                 ajacayan oriente
# 201827                         el techale (tlaltechale)
# 205443                                     xalpatlahuac
# 205605                                        tehuixtla
# 207576                                      san vicente
# 218826                              san miguel totolapa
# 229834                                         ocopexco
# 232556                      ciudad apaxtla de castrejon
# 234234                                       teloloapan
# 236356                                arroyo totole uno
# 246638                                        tehuixtla
# 253778                                         atlixtac
# 256615                                      buena vista
# 266709                                      el aguajito
# 268075                                      san vicente
# 270992                      ciudad apaxtla de castrejon
#
#                                             KEY_benef_loc  \
# 43112                 huitzuco de los figueroa-lagunillas
# 47378                      tlapa de comonfort-chiepetepec
# 52711                               teloloapan-cerro alto
# 72145              leonardo bravo-coatepec de la escalera
# 72232                               teloloapan-cerro alto
# 75583                              tetipac-chontalcoatlan
# 86238                cutzamala de pinzon-tlanexpa (nexpa)
# 95993      atlixtac-huitzapula (san pedro huitzapula sur)
# 96689                       zapotitlan tablas-san agustin
# 100867                             tecoanapa-los saucitos
# 102479              zapotitlan tablas-escalerilla lagunas
# 107838                              teloloapan-teloloapan
# 107946                        chilapa de alvarez-papaxtla
# 111030                general heliodoro castillo-izotepec
# 118507                huitzuco de los figueroa-quetzalapa
# 118997             teloloapan-el ahuacatito (el aguacate)
# 121404            general heliodoro castillo-la primavera
# 127061  juan r. escudero-san juan del reparo norte (sa...
# 138943                     teloloapan-huerta grande norte
# 139710                                    olinala-olinala
# 144478  metlatonoc-cocuilotlazala (cocuitlazala el viejo)
# 146918                         tecoanapa-la perseverancia
# 149044                              teloloapan-oxtotitlan
# 153728                               pilcaya-cacahuamilpa
# 163527                             tecoanapa-los saucitos
# 177186                               tecoanapa-huamuchapa
# 182894              chilpancingo de los bravo-san vicente
# 186704                     chilapa de alvarez-atzacoaloya
# 187303            general heliodoro castillo-la primavera
# 190290              tlapehuala-san antonio de las huertas
# 191216              chilpancingo de los bravo-san vicente
# 195509                           san marcos-santo domingo
# 198631           jose joaquin de herrera-ajacayan oriente
# 201827                 tecoanapa-el techale (tlaltechale)
# 205443                             tecoanapa-xalpatlahuac
# 205605                               teloloapan-tehuixtla
# 207576              chilpancingo de los bravo-san vicente
# 218826                   huamuxtitlan-san miguel totolapa
# 229834                                  atlixtac-ocopexco
# 232556                apaxtla-ciudad apaxtla de castrejon
# 234234                              teloloapan-teloloapan
# 236356                   xochistlahuaca-arroyo totole uno
# 246638                               teloloapan-tehuixtla
# 253778                                  atlixtac-atlixtac
# 256615                             metlatonoc-buena vista
# 266709              chilpancingo de los bravo-el aguajito
# 268075              chilpancingo de los bravo-san vicente
# 270992                apaxtla-ciudad apaxtla de castrejon
#
#                    MUNICIPIO_Clean  \
# 43112     huitzuco de los figueroa
# 47378           tlapa de comonfort
# 52711                   teloloapan
# 72145               leonardo bravo
# 72232                   teloloapan
# 75583                      tetipac
# 86238          cutzamala de pinzon
# 95993                     atlixtac
# 96689            zapotitlan tablas
# 100867                   tecoanapa
# 102479           zapotitlan tablas
# 107838                  teloloapan
# 107946          chilapa de alvarez
# 111030  general heliodoro castillo
# 118507    huitzuco de los figueroa
# 118997                  teloloapan
# 121404  general heliodoro castillo
# 127061            juan r. escudero
# 138943                  teloloapan
# 139710                     olinala
# 144478                  metlatonoc
# 146918                   tecoanapa
# 149044                  teloloapan
# 153728                     pilcaya
# 163527                   tecoanapa
# 177186                   tecoanapa
# 182894   chilpancingo de los bravo
# 186704          chilapa de alvarez
# 187303  general heliodoro castillo
# 190290                  tlapehuala
# 191216   chilpancingo de los bravo
# 195509                  san marcos
# 198631     jose joaquin de herrera
# 201827                   tecoanapa
# 205443                   tecoanapa
# 205605                  teloloapan
# 207576   chilpancingo de los bravo
# 218826                huamuxtitlan
# 229834                    atlixtac
# 232556                     apaxtla
# 234234                  teloloapan
# 236356              xochistlahuaca
# 246638                  teloloapan
# 253778                    atlixtac
# 256615                  metlatonoc
# 266709   chilpancingo de los bravo
# 268075   chilpancingo de los bravo
# 270992                     apaxtla
#
#                                         LOCALIDAD_Clean  \
# 43112                                        lagunillas
# 47378                                       chiepetepec
# 52711                                        cerro alto
# 72145                           coatepec de la escalera
# 72232                                        cerro alto
# 75583                                    chontalcoatlan
# 86238                                  tlanexpa (nexpa)
# 95993             huitzapula (san pedro huitzapula sur)
# 96689                                       san agustin
# 100867                                     los saucitos
# 102479                              escalerilla lagunas
# 107838                                       teloloapan
# 107946                                         papaxtla
# 111030                                         izotepec
# 118507                                       quetzalapa
# 118997                      el ahuacatito (el aguacate)
# 121404                                     la primavera
# 127061  san juan del reparo norte (san juan del reparo)
# 138943                              huerta grande norte
# 139710                                          olinala
# 144478           cocuilotlazala (cocuitlazala el viejo)
# 146918                                 la perseverancia
# 149044                                       oxtotitlan
# 153728                                     cacahuamilpa
# 163527                                     los saucitos
# 177186                                       huamuchapa
# 182894                                      san vicente
# 186704                                      atzacoaloya
# 187303                                     la primavera
# 190290                       san antonio de las huertas
# 191216                                      san vicente
# 195509                                    santo domingo
# 198631                                 ajacayan oriente
# 201827                         el techale (tlaltechale)
# 205443                                     xalpatlahuac
# 205605                                        tehuixtla
# 207576                                      san vicente
# 218826                              san miguel totolapa
# 229834                                         ocopexco
# 232556                      ciudad apaxtla de castrejon
# 234234                                       teloloapan
# 236356                                arroyo totole uno
# 246638                                        tehuixtla
# 253778                                         atlixtac
# 256615                                      buena vista
# 266709                                      el aguajito
# 268075                                      san vicente
# 270992                      ciudad apaxtla de castrejon
#
#                                         Municipio-loc-KEY
# 43112                 huitzuco de los figueroa-lagunillas
# 47378                      tlapa de comonfort-chiepetepec
# 52711                               teloloapan-cerro alto
# 72145              leonardo bravo-coatepec de la escalera
# 72232                               teloloapan-cerro alto
# 75583                              tetipac-chontalcoatlan
# 86238                cutzamala de pinzon-tlanexpa (nexpa)
# 95993      atlixtac-huitzapula (san pedro huitzapula sur)
# 96689                       zapotitlan tablas-san agustin
# 100867                             tecoanapa-los saucitos
# 102479              zapotitlan tablas-escalerilla lagunas
# 107838                              teloloapan-teloloapan
# 107946                        chilapa de alvarez-papaxtla
# 111030                general heliodoro castillo-izotepec
# 118507                huitzuco de los figueroa-quetzalapa
# 118997             teloloapan-el ahuacatito (el aguacate)
# 121404            general heliodoro castillo-la primavera
# 127061  juan r. escudero-san juan del reparo norte (sa...
# 138943                     teloloapan-huerta grande norte
# 139710                                    olinala-olinala
# 144478  metlatonoc-cocuilotlazala (cocuitlazala el viejo)
# 146918                         tecoanapa-la perseverancia
# 149044                              teloloapan-oxtotitlan
# 153728                               pilcaya-cacahuamilpa
# 163527                             tecoanapa-los saucitos
# 177186                               tecoanapa-huamuchapa
# 182894              chilpancingo de los bravo-san vicente
# 186704                     chilapa de alvarez-atzacoaloya
# 187303            general heliodoro castillo-la primavera
# 190290              tlapehuala-san antonio de las huertas
# 191216              chilpancingo de los bravo-san vicente
# 195509                           san marcos-santo domingo
# 198631           jose joaquin de herrera-ajacayan oriente
# 201827                 tecoanapa-el techale (tlaltechale)
# 205443                             tecoanapa-xalpatlahuac
# 205605                               teloloapan-tehuixtla
# 207576              chilpancingo de los bravo-san vicente
# 218826                   huamuxtitlan-san miguel totolapa
# 229834                                  atlixtac-ocopexco
# 232556                apaxtla-ciudad apaxtla de castrejon
# 234234                              teloloapan-teloloapan
# 236356                   xochistlahuaca-arroyo totole uno
# 246638                               teloloapan-tehuixtla
# 253778                                  atlixtac-atlixtac
# 256615                             metlatonoc-buena vista
# 266709              chilpancingo de los bravo-el aguajito
# 268075              chilpancingo de los bravo-san vicente
# 270992                apaxtla-ciudad apaxtla de castrejon

# %%
listado_beneficiarios_2019_match = listado_beneficiarios_2019_match.drop_duplicates()

# %%
listado_beneficiarios_2019_match
# Out:
#                           BENEFICIARIO         ZONA   ENTIDAD  \
# 0          HERNANDEZ MORALES BERNARDO      NACIONAL    Puebla
# 1       GUZMAN VARGAS CELEDONIA JUANA      NACIONAL  Guerrero
# 2            REFUGIO RIVERA VALENTINA      NACIONAL  Guerrero
# 3                LOPEZ GUZMAN AGAPITO      NACIONAL  Guerrero
# 4              SALINAS SALGADO FELIPE      NACIONAL  Guerrero
# ...                                ...          ...       ...
# 276549        CASTILLO CUEVAS AMANCIO   CENTRO PAÍS  GUERRERO
# 276550       RUEDA SECUNDINO ANACLETO   CENTRO PAÍS  GUERRERO
# 276551          ARMENTA VILLEGAS LUIS   CENTRO PAÍS  GUERRERO
# 276552         BELLO JIMENEZ GREGORIA   CENTRO PAÍS  GUERRERO
# 276553     CASIMIRO MARTINEZ ELIBORIA   CENTRO PAÍS  GUERRERO
#
#                        MUNICIPIO     LOCALIDAD               PRODUCTO  \
# 0       San Sebastián Tlacotepec      NACIONAL  Cultivo de maíz grano
# 1                   Malinaltepec      NACIONAL  Cultivo de maíz grano
# 2                   Malinaltepec      NACIONAL  Cultivo de maíz grano
# 3                 Xochistlahuaca      NACIONAL  Cultivo de maíz grano
# 4                     Teloloapan      NACIONAL  Cultivo de maíz grano
# ...                          ...           ...                    ...
# 276549          TAXCO DE ALARCÓN       PAINTLA  Cultivo de maíz grano
# 276550          TAXCO DE ALARCÓN       PAINTLA  Cultivo de maíz grano
# 276551                    COCULA        COCULA  Cultivo de maíz grano
# 276552                  ATLIXTAC  XALPITZÁHUAC  Cultivo de maíz grano
# 276553          TAXCO DE ALARCÓN       PAINTLA  Cultivo de maíz grano
#
#              FECHA  MONTO FEDERAL CICLO AGRÍCOLA ENTIDAD_c_benef  \
# 0             2019        2191.55         PV2019          puebla
# 1             2019        6813.65         PV2019        guerrero
# 2             2019        6813.65         PV2019        guerrero
# 3             2019        4383.10         PV2019        guerrero
# 4             2019        2430.55         PV2019        guerrero
# ...            ...            ...            ...             ...
# 276549  27/06/2019        2430.55         PV2019        guerrero
# 276550  27/06/2019        2430.55         PV2019        guerrero
# 276551  06/07/2019        2430.55         PV2019        guerrero
# 276552  15/07/2019        6574.65         PV2019        guerrero
# 276553  27/06/2019        2430.55         PV2019        guerrero
#
#                MUNICIPIO_c_benef LOCALIDAD_c_benef  \
# 0       san sebastian tlacotepec          nacional
# 1                   malinaltepec          nacional
# 2                   malinaltepec          nacional
# 3                 xochistlahuaca          nacional
# 4                     teloloapan          nacional
# ...                          ...               ...
# 276549          taxco de alarcon           paintla
# 276550          taxco de alarcon           paintla
# 276551                    cocula            cocula
# 276552                  atlixtac      xalpitzahuac
# 276553          taxco de alarcon           paintla
#
#                             KEY_benef_loc           MUNICIPIO_Clean  \
# 0       san sebastian tlacotepec-nacional  san sebastian tlacotepec
# 1                   malinaltepec-nacional              malinaltepec
# 2                   malinaltepec-nacional              malinaltepec
# 3                 xochistlahuaca-nacional            xochistlahuaca
# 4                     teloloapan-nacional                teloloapan
# ...                                   ...                       ...
# 276549           taxco de alarcon-paintla          taxco de alarcon
# 276550           taxco de alarcon-paintla          taxco de alarcon
# 276551                      cocula-cocula                    cocula
# 276552              atlixtac-xalpitzahuac                  atlixtac
# 276553           taxco de alarcon-paintla          taxco de alarcon
#
#        LOCALIDAD_Clean                  Municipio-loc-KEY
# 0             nacional  san sebastian tlacotepec-nacional
# 1             nacional              malinaltepec-nacional
# 2             nacional              malinaltepec-nacional
# 3             nacional            xochistlahuaca-nacional
# 4             nacional                teloloapan-nacional
# ...                ...                                ...
# 276549         paintla           taxco de alarcon-paintla
# 276550         paintla           taxco de alarcon-paintla
# 276551          cocula                      cocula-cocula
# 276552    xalpitzahuac              atlixtac-xalpitzahuac
# 276553         paintla           taxco de alarcon-paintla
#
# [276506 rows x 16 columns]

# %%
# Hacer el join de la Parte I
listado_beneficiarios_parte_I_localidades = pd.merge(listado_beneficiarios_2019_match, diccionario_LOC_19_simple, left_on="Municipio-loc-KEY",
                                         right_on="KEY_benef_loc", how='left', suffixes=('_benef', '_inegi'))

# %%
listado_beneficiarios_parte_I_localidades.shape
# Out:
# (276506, 19)

# %%
# Marcar todos los duplicados en las columnas 'columna1' y 'columna2' como True
duplicados = listado_beneficiarios_parte_I_localidades.duplicated()

# Filtrar el DataFrame original para mostrar solo los duplicados
df_duplicados = listado_beneficiarios_parte_I_localidades[duplicados]

# %%
df_duplicados
# Out:
# Empty DataFrame
# Columns: [BENEFICIARIO, ZONA, ENTIDAD, MUNICIPIO, LOCALIDAD, PRODUCTO, FECHA, MONTO FEDERAL, CICLO AGRÍCOLA, ENTIDAD_c_benef, MUNICIPIO_c_benef, LOCALIDAD_c_benef, KEY_benef_loc_benef, MUNICIPIO_Clean, LOCALIDAD_Clean, Municipio-loc-KEY, KEY_benef_loc_inegi, match_score, KEY_inegi_localidad]
# Index: []

# %%
listado_beneficiarios_parte_I_localidades.drop_duplicates(keep='first', inplace=True)

# %%
listado_beneficiarios_parte_I_localidades.shape
# Out:
# (276506, 19)

# %%
listado_beneficiarios_parte_I_localidades.isna().sum()
# Out:
# BENEFICIARIO              0
# ZONA                      0
# ENTIDAD                   0
# MUNICIPIO                 0
# LOCALIDAD                 0
# PRODUCTO                  0
# FECHA                     0
# MONTO FEDERAL             0
# CICLO AGRÍCOLA            0
# ENTIDAD_c_benef           0
# MUNICIPIO_c_benef         0
# LOCALIDAD_c_benef         0
# KEY_benef_loc_benef       0
# MUNICIPIO_Clean           0
# LOCALIDAD_Clean           0
# Municipio-loc-KEY         0
# KEY_benef_loc_inegi       0
# match_score            1488
# KEY_inegi_localidad       0
# dtype: int64

# %%
# Assuming listado_beneficiarios_parte_II is your DataFrame
rows_with_nan = listado_beneficiarios_parte_I_localidades[listado_beneficiarios_parte_I_localidades.isna().any(axis=1)]

# rows_with_nan now contains only the rows with NaN values in any column

# %%
rows_with_nan['KEY_benef_loc_benef'].unique()
# Out:
# array(['xochistlahuaca-nacional', 'teloloapan-nacional',
#        'xalpatlahuac-nacional', 'san miguel totolapan-nacional',
#        'jose joaquin de herrera-nacional', 'taxco de alarcon-nacional',
#        'iguala de la independencia-nacional',
#        'coyuca de catalan-nacional', 'ayutla de los libres-nacional',
#        'atlixtac-nacional', 'quechultenango-nacional', 'arcelia-nacional',
#        'alcozauca de guerrero-nacional',
#        'ajuchitlan del progreso-nacional', 'acatepec-nacional',
#        'zitlala-nacional', 'igualapa-nacional',
#        'cutzamala de pinzon-nacional', 'olinala-nacional',
#        'cochoapa el grande-nacional', 'petatlan-nacional',
#        'tlalchapa-nacional', 'general heliodoro castillo-nacional',
#        'tecoanapa-nacional', 'tixtla de guerrero-nacional',
#        'cuetzala del progreso-nacional', 'azoyu-nacional',
#        'juan r. escudero-nacional', 'martir de cuilapan-nacional',
#        'ometepec-nacional', 'san marcos-nacional', 'copanatoyac-nacional',
#        'la union de isidoro montes de oca-nacional',
#        'general canuto a. neri-nacional', 'tecpan de galeana-nacional',
#        'zapotitlan tablas-nacional', 'leonardo bravo-nacional',
#        'florencio villarreal-nacional', 'benito juarez-nacional',
#        'atoyac de alvarez-nacional',
#        'coahuayutla de jose maria izazaga-nacional', 'tlacoapa-nacional',
#        'chilpancingo de los bravo-nacional',
#        'acapulco de juarez-nacional', 'huamuxtitlan-nacional',
#        'zihuatanejo de azueta-nacional', 'juchitan-nacional',
#        'metlatonoc-nacional', 'tlacoachistlahuaca-nacional',
#        'coyuca de benitez-nacional', 'pilcaya-nacional',
#        'tlapa de comonfort-nacional', 'cocula-nacional',
#        'tlalchapa-ninguno'], dtype=object)

# %%
print(listado_beneficiarios_parte_I_localidades['KEY_inegi_localidad'].duplicated().sum())
print(INEGI_UNIQUELOC_2019['KEY_inegi_localidad'].duplicated().sum())
# Out:
# 271980
# 0

# %%
# TODO: REVISAR ESTA PARTE (ARTURO)
listado_beneficiarios_parte_II_localidades = pd.merge(listado_beneficiarios_parte_I_localidades, INEGI_UNIQUELOC_2019,
                                          left_on="KEY_inegi_localidad",
                                          right_on="KEY_inegi_localidad", how='left', suffixes=('_benef', '_inegi'))

# %%
listado_beneficiarios_parte_II_localidades.isna().sum()
# Out:
# BENEFICIARIO              0
# ZONA                      0
# ENTIDAD                   0
# MUNICIPIO                 0
# LOCALIDAD                 0
# PRODUCTO                  0
# FECHA                     0
# MONTO FEDERAL             0
# CICLO AGRÍCOLA            0
# ENTIDAD_c_benef           0
# MUNICIPIO_c_benef         0
# LOCALIDAD_c_benef         0
# KEY_benef_loc_benef       0
# MUNICIPIO_Clean           0
# LOCALIDAD_Clean           0
# Municipio-loc-KEY         0
# KEY_benef_loc_inegi       0
# match_score            1488
# KEY_inegi_localidad       0
# CVE_ENT                   0
# Entidad_inegi             0
# CVE_MUN                   0
# Municipio_inegi           0
# CVE_LOC                   0
# Localidad_inegi           0
# KEY_inegi_municipio       0
# dtype: int64

# %%
# Assuming listado_beneficiarios_parte_II is your DataFrame
rows_with_nan = listado_beneficiarios_parte_II_localidades[listado_beneficiarios_parte_II_localidades.isna().any(axis=1)]

# rows_with_nan now contains only the rows with NaN values in any column

# %%
rows_with_nan[rows_with_nan['Entidad_inegi'].isna()]
# Out:
# Empty DataFrame
# Columns: [BENEFICIARIO, ZONA, ENTIDAD, MUNICIPIO, LOCALIDAD, PRODUCTO, FECHA, MONTO FEDERAL, CICLO AGRÍCOLA, ENTIDAD_c_benef, MUNICIPIO_c_benef, LOCALIDAD_c_benef, KEY_benef_loc_benef, MUNICIPIO_Clean, LOCALIDAD_Clean, Municipio-loc-KEY, KEY_benef_loc_inegi, match_score, KEY_inegi_localidad, CVE_ENT, Entidad_inegi, CVE_MUN, Municipio_inegi, CVE_LOC, Localidad_inegi, KEY_inegi_municipio]
# Index: []
#
# [0 rows x 26 columns]

# %%
rows_with_nan.tail(50)
# Out:
#                               BENEFICIARIO         ZONA   ENTIDAD  \
# 1479              SANDOVAL SALGADO FELIPE      NACIONAL  Guerrero
# 1480                    ARTEAGA VELA INES      NACIONAL  Guerrero
# 1481              BASAN GUATEMALA CARMELO      NACIONAL  Guerrero
# 1482             ALVAREZ RABADAN VIRGINIA      NACIONAL  Guerrero
# 1483               PEREZ HERNANDEZ VIANEY      NACIONAL  Guerrero
# 1484       SALGADO MONTES DE OCA EZEQUIEL      NACIONAL  Guerrero
# 1485        MELGOZA SALMERON ESTHER VELIA      NACIONAL  Guerrero
# 1486                NAZARIO ONOFRE LUCILA      NACIONAL  Guerrero
# 1487                 ROMAN SALGADO NELIDA      NACIONAL  Guerrero
# 1488               RODRIGUEZ SAHAGUN LUIS      NACIONAL  Guerrero
# 1489               AVILA SALADO CELESTINO      NACIONAL  Guerrero
# 1490         CARACHURE MARTINEZ ESPERANZA      NACIONAL  Guerrero
# 1491            CALDERON ARELLANO BERTINA      NACIONAL  Guerrero
# 1492    GONZALEZ VILLA HUMBERTO LODEGARIO      NACIONAL  Guerrero
# 1493             MERCADO RODRIGUEZ FELIPE      NACIONAL  Guerrero
# 1494              VARGAS DAMAZO FILIBERTO      NACIONAL  Guerrero
# 1495               VALLEJO CASTRO MARISOL      NACIONAL  Guerrero
# 1496                 ROMAN SALGADO MANUEL      NACIONAL  Guerrero
# 1497               ROMAN MIRANDA MARICELA      NACIONAL  Guerrero
# 1498               MIRANDA MARTINEZ ROSIO      NACIONAL  Guerrero
# 1499                  ROMAN MIRANDA NORMA      NACIONAL  Guerrero
# 1500                JIMENEZ ANCELMO PABLO      NACIONAL  Guerrero
# 1502        GUTIERREZ URCINO MIGUEL ANGEL      NACIONAL  Guerrero
# 1503    BUSTAMANTE HERNANDEZ KAREN NAYELI      NACIONAL  Guerrero
# 1504              SUASTEGUI VAZQUEZ NELLY      NACIONAL  Guerrero
# 1505                 GOMEZ GALLARDO PEDRO      NACIONAL  Guerrero
# 1507         SOLANO ORTEGA CRUZ ALEJANDRO      NACIONAL  Guerrero
# 1508                SOLANO ORTEGA DARILIA      NACIONAL  Guerrero
# 1509              NAJERA SALGADO APOLINAR      NACIONAL  Guerrero
# 1510            PERALTA CALDERON ALBAYENI      NACIONAL  Guerrero
# 1511            SANCHEZ NAVA MA. DE JESUS      NACIONAL  Guerrero
# 1512          DELGADO LEODEGARIO MA. CRUZ      NACIONAL  Guerrero
# 1513          JIMENEZ PALACIOS ROSA ELENA      NACIONAL  Guerrero
# 1514                AGUILAR BARRERA SOFIA      NACIONAL  Guerrero
# 1515                 ERAZO BAHENA MARCELA      NACIONAL  Guerrero
# 1516           BUSTAMANTE BARBOZA CLAUDIO      NACIONAL  Guerrero
# 1517                    MAYO VALENTE ABEL      NACIONAL  Guerrero
# 1518              DELGADO LOPEZ GUADALUPE      NACIONAL  Guerrero
# 1519                  PABLO GOMEZ EUDOCIA      NACIONAL  Guerrero
# 1520                 ORTEGA CASIMIRO EMMA      NACIONAL  Guerrero
# 1521          SECUNDINO VICTORIANO MARCOS      NACIONAL  Guerrero
# 1522             HERNANDEZ SALMERON MARIO      NACIONAL  Guerrero
# 1523               BARBOZA SALGADO BERTHA      NACIONAL  Guerrero
# 1524                 SOTELO ROMAN DOMINGA      NACIONAL  Guerrero
# 1526                   DAMASO TOMAS MARIA      NACIONAL  Guerrero
# 1527           HERRERA VILLANUEVA VALENTE      NACIONAL  Guerrero
# 1528                 CRUZ NAJERA PERFECTO      NACIONAL  Guerrero
# 1529              CARRILLO VALENTE ISMAEL      NACIONAL  Guerrero
# 1530               BELLO ARIZMENDI MARINO      NACIONAL  Guerrero
# 275401             GUTIERREZ GARCIA JUANA   CENTRO PAÍS  GUERRERO
#
#                                 MUNICIPIO LOCALIDAD               PRODUCTO  \
# 1479                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1480                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1481                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1482                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1483                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1484                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1485                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1486                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1487                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1488                 San Miguel Totolapan  NACIONAL  Cultivo de maíz grano
# 1489                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1490                 San Miguel Totolapan  NACIONAL  Cultivo de maíz grano
# 1491                 San Miguel Totolapan  NACIONAL  Cultivo de maíz grano
# 1492                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1493    Coahuayutla de José María Izazaga  NACIONAL  Cultivo de maíz grano
# 1494                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1495                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1496                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1497                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1498                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1499                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1500                   Mártir de Cuilapan  NACIONAL  Cultivo de maíz grano
# 1502                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1503                 San Miguel Totolapan  NACIONAL  Cultivo de maíz grano
# 1504                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1505                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1507                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1508                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1509                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1510                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1511                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1512                 San Miguel Totolapan  NACIONAL  Cultivo de maíz grano
# 1513                 San Miguel Totolapan  NACIONAL  Cultivo de maíz grano
# 1514                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1515                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1516                 San Miguel Totolapan  NACIONAL  Cultivo de maíz grano
# 1517                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1518                           Teloloapan  NACIONAL  Cultivo de maíz grano
# 1519                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1520                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1521                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1522                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1523                 San Miguel Totolapan  NACIONAL  Cultivo de maíz grano
# 1524                 San Miguel Totolapan  NACIONAL  Cultivo de maíz grano
# 1526                 San Miguel Totolapan  NACIONAL  Cultivo de maíz grano
# 1527                 Ayutla de los Libres  NACIONAL  Cultivo de maíz grano
# 1528                    Atoyac de Álvarez  NACIONAL  Cultivo de maíz grano
# 1529                            Tecoanapa  NACIONAL  Cultivo de maíz grano
# 1530                     Juan R. Escudero  NACIONAL  Cultivo de maíz grano
# 275401                          TLALCHAPA   NINGUNO  Cultivo de maíz grano
#
#              FECHA  MONTO FEDERAL CICLO AGRÍCOLA ENTIDAD_c_benef  ...  \
# 1479          2019        2430.55         PV2019        guerrero  ...
# 1480          2019        2191.55         PV2019        guerrero  ...
# 1481          2019        4383.10         PV2019        guerrero  ...
# 1482          2019        2430.55         PV2019        guerrero  ...
# 1483          2019        2191.55         PV2019        guerrero  ...
# 1484          2019        2430.55         PV2019        guerrero  ...
# 1485          2019        4383.10         PV2019        guerrero  ...
# 1486          2019        2191.55         PV2019        guerrero  ...
# 1487          2019        2430.55         PV2019        guerrero  ...
# 1488          2019        4383.10         PV2019        guerrero  ...
# 1489          2019        4383.10         PV2019        guerrero  ...
# 1490          2019        4383.10         PV2019        guerrero  ...
# 1491          2019        4383.10         PV2019        guerrero  ...
# 1492          2019        2191.55         PV2019        guerrero  ...
# 1493          2019         239.00         PV2019        guerrero  ...
# 1494          2019        4383.10         PV2019        guerrero  ...
# 1495          2019        4383.10         PV2019        guerrero  ...
# 1496          2019        2191.55         PV2019        guerrero  ...
# 1497          2019        2191.55         PV2019        guerrero  ...
# 1498          2019        2191.55         PV2019        guerrero  ...
# 1499          2019        2191.55         PV2019        guerrero  ...
# 1500          2019         239.00         PV2019        guerrero  ...
# 1502          2019        2430.55         PV2019        guerrero  ...
# 1503          2019        4622.10         PV2019        guerrero  ...
# 1504          2019        2191.55         PV2019        guerrero  ...
# 1505          2019        4383.10         PV2019        guerrero  ...
# 1507          2019        2430.55         PV2019        guerrero  ...
# 1508          2019        2430.55         PV2019        guerrero  ...
# 1509          2019        2430.55         PV2019        guerrero  ...
# 1510          2019        2430.55         PV2019        guerrero  ...
# 1511          2019        2191.55         PV2019        guerrero  ...
# 1512          2019        4622.10         PV2019        guerrero  ...
# 1513          2019        4383.10         PV2019        guerrero  ...
# 1514          2019        2430.55         PV2019        guerrero  ...
# 1515          2019        2191.55         PV2019        guerrero  ...
# 1516          2019        4383.10         PV2019        guerrero  ...
# 1517          2019        2191.55         PV2019        guerrero  ...
# 1518          2019        2191.55         PV2019        guerrero  ...
# 1519          2019        4383.10         PV2019        guerrero  ...
# 1520          2019        2191.55         PV2019        guerrero  ...
# 1521          2019        4383.10         PV2019        guerrero  ...
# 1522          2019        2191.55         PV2019        guerrero  ...
# 1523          2019        4622.10         PV2019        guerrero  ...
# 1524          2019        4622.10         PV2019        guerrero  ...
# 1526          2019        4622.10         PV2019        guerrero  ...
# 1527          2019        2307.60         PV2019        guerrero  ...
# 1528          2019         239.00         PV2019        guerrero  ...
# 1529          2019        6574.65         PV2019        guerrero  ...
# 1530          2019        4861.10         PV2019        guerrero  ...
# 275401  11/09/2019        2513.88         PV2019        guerrero  ...
#
#                                KEY_benef_loc_inegi match_score  \
# 1479                           teloloapan-nacional         NaN
# 1480                           teloloapan-nacional         NaN
# 1481                            tecoanapa-nacional         NaN
# 1482                           teloloapan-nacional         NaN
# 1483                           teloloapan-nacional         NaN
# 1484                           teloloapan-nacional         NaN
# 1485                            tecoanapa-nacional         NaN
# 1486                           teloloapan-nacional         NaN
# 1487                           teloloapan-nacional         NaN
# 1488                 san miguel totolapan-nacional         NaN
# 1489                            tecoanapa-nacional         NaN
# 1490                 san miguel totolapan-nacional         NaN
# 1491                 san miguel totolapan-nacional         NaN
# 1492                           teloloapan-nacional         NaN
# 1493    coahuayutla de jose maria izazaga-nacional         NaN
# 1494                            tecoanapa-nacional         NaN
# 1495                           teloloapan-nacional         NaN
# 1496                           teloloapan-nacional         NaN
# 1497                           teloloapan-nacional         NaN
# 1498                           teloloapan-nacional         NaN
# 1499                           teloloapan-nacional         NaN
# 1500                   martir de cuilapan-nacional         NaN
# 1502                           teloloapan-nacional         NaN
# 1503                 san miguel totolapan-nacional         NaN
# 1504                            tecoanapa-nacional         NaN
# 1505                            tecoanapa-nacional         NaN
# 1507                           teloloapan-nacional         NaN
# 1508                           teloloapan-nacional         NaN
# 1509                           teloloapan-nacional         NaN
# 1510                           teloloapan-nacional         NaN
# 1511                           teloloapan-nacional         NaN
# 1512                 san miguel totolapan-nacional         NaN
# 1513                 san miguel totolapan-nacional         NaN
# 1514                           teloloapan-nacional         NaN
# 1515                           teloloapan-nacional         NaN
# 1516                 san miguel totolapan-nacional         NaN
# 1517                            tecoanapa-nacional         NaN
# 1518                           teloloapan-nacional         NaN
# 1519                            tecoanapa-nacional         NaN
# 1520                            tecoanapa-nacional         NaN
# 1521                            tecoanapa-nacional         NaN
# 1522                            tecoanapa-nacional         NaN
# 1523                 san miguel totolapan-nacional         NaN
# 1524                 san miguel totolapan-nacional         NaN
# 1526                 san miguel totolapan-nacional         NaN
# 1527                 ayutla de los libres-nacional         NaN
# 1528                    atoyac de alvarez-nacional         NaN
# 1529                            tecoanapa-nacional         NaN
# 1530                     juan r. escudero-nacional         NaN
# 275401                           tlalchapa-ninguno         NaN
#
#                                       KEY_inegi_localidad CVE_ENT  \
# 1479                                teloloapan-teloloapan      12
# 1480                                teloloapan-teloloapan      12
# 1481                                  tecoanapa-tecoanapa      12
# 1482                                teloloapan-teloloapan      12
# 1483                                teloloapan-teloloapan      12
# 1484                                teloloapan-teloloapan      12
# 1485                                  tecoanapa-tecoanapa      12
# 1486                                teloloapan-teloloapan      12
# 1487                                teloloapan-teloloapan      12
# 1488            san miguel totolapan-san miguel totolapan      12
# 1489                                  tecoanapa-tecoanapa      12
# 1490            san miguel totolapan-san miguel totolapan      12
# 1491            san miguel totolapan-san miguel totolapan      12
# 1492                                teloloapan-teloloapan      12
# 1493    coahuayutla de jose maria izazaga-coahuayutla ...      12
# 1494                                  tecoanapa-tecoanapa      12
# 1495                                teloloapan-teloloapan      12
# 1496                                teloloapan-teloloapan      12
# 1497                                teloloapan-teloloapan      12
# 1498                                teloloapan-teloloapan      12
# 1499                                teloloapan-teloloapan      12
# 1500                            martir de cuilapan-apango      12
# 1502                                teloloapan-teloloapan      12
# 1503            san miguel totolapan-san miguel totolapan      12
# 1504                                  tecoanapa-tecoanapa      12
# 1505                                  tecoanapa-tecoanapa      12
# 1507                                teloloapan-teloloapan      12
# 1508                                teloloapan-teloloapan      12
# 1509                                teloloapan-teloloapan      12
# 1510                                teloloapan-teloloapan      12
# 1511                                teloloapan-teloloapan      12
# 1512            san miguel totolapan-san miguel totolapan      12
# 1513            san miguel totolapan-san miguel totolapan      12
# 1514                                teloloapan-teloloapan      12
# 1515                                teloloapan-teloloapan      12
# 1516            san miguel totolapan-san miguel totolapan      12
# 1517                                  tecoanapa-tecoanapa      12
# 1518                                teloloapan-teloloapan      12
# 1519                                  tecoanapa-tecoanapa      12
# 1520                                  tecoanapa-tecoanapa      12
# 1521                                  tecoanapa-tecoanapa      12
# 1522                                  tecoanapa-tecoanapa      12
# 1523            san miguel totolapan-san miguel totolapan      12
# 1524            san miguel totolapan-san miguel totolapan      12
# 1526            san miguel totolapan-san miguel totolapan      12
# 1527            ayutla de los libres-ayutla de los libres      12
# 1528                  atoyac de alvarez-atoyac de alvarez      12
# 1529                                  tecoanapa-tecoanapa      12
# 1530                     juan r. escudero-tierra colorada      12
# 275401                                  tlalchapa-ninguno      12
#
#        Entidad_inegi CVE_MUN                    Municipio_inegi  CVE_LOC  \
# 1479        Guerrero     058                         Teloloapan     0001
# 1480        Guerrero     058                         Teloloapan     0001
# 1481        Guerrero     056                          Tecoanapa     0001
# 1482        Guerrero     058                         Teloloapan     0001
# 1483        Guerrero     058                         Teloloapan     0001
# 1484        Guerrero     058                         Teloloapan     0001
# 1485        Guerrero     056                          Tecoanapa     0001
# 1486        Guerrero     058                         Teloloapan     0001
# 1487        Guerrero     058                         Teloloapan     0001
# 1488        Guerrero     054               San Miguel Totolapan     0001
# 1489        Guerrero     056                          Tecoanapa     0001
# 1490        Guerrero     054               San Miguel Totolapan     0001
# 1491        Guerrero     054               San Miguel Totolapan     0001
# 1492        Guerrero     058                         Teloloapan     0001
# 1493        Guerrero     016  Coahuayutla de José María Izazaga     0001
# 1494        Guerrero     056                          Tecoanapa     0001
# 1495        Guerrero     058                         Teloloapan     0001
# 1496        Guerrero     058                         Teloloapan     0001
# 1497        Guerrero     058                         Teloloapan     0001
# 1498        Guerrero     058                         Teloloapan     0001
# 1499        Guerrero     058                         Teloloapan     0001
# 1500        Guerrero     042                 Mártir de Cuilapan     0001
# 1502        Guerrero     058                         Teloloapan     0001
# 1503        Guerrero     054               San Miguel Totolapan     0001
# 1504        Guerrero     056                          Tecoanapa     0001
# 1505        Guerrero     056                          Tecoanapa     0001
# 1507        Guerrero     058                         Teloloapan     0001
# 1508        Guerrero     058                         Teloloapan     0001
# 1509        Guerrero     058                         Teloloapan     0001
# 1510        Guerrero     058                         Teloloapan     0001
# 1511        Guerrero     058                         Teloloapan     0001
# 1512        Guerrero     054               San Miguel Totolapan     0001
# 1513        Guerrero     054               San Miguel Totolapan     0001
# 1514        Guerrero     058                         Teloloapan     0001
# 1515        Guerrero     058                         Teloloapan     0001
# 1516        Guerrero     054               San Miguel Totolapan     0001
# 1517        Guerrero     056                          Tecoanapa     0001
# 1518        Guerrero     058                         Teloloapan     0001
# 1519        Guerrero     056                          Tecoanapa     0001
# 1520        Guerrero     056                          Tecoanapa     0001
# 1521        Guerrero     056                          Tecoanapa     0001
# 1522        Guerrero     056                          Tecoanapa     0001
# 1523        Guerrero     054               San Miguel Totolapan     0001
# 1524        Guerrero     054               San Miguel Totolapan     0001
# 1526        Guerrero     054               San Miguel Totolapan     0001
# 1527        Guerrero     012               Ayutla de los Libres     0001
# 1528        Guerrero     011                  Atoyac de Álvarez     0001
# 1529        Guerrero     056                          Tecoanapa     0001
# 1530        Guerrero     039                   Juan R. Escudero     0001
# 275401      Guerrero     064                          Tlalchapa     0071
#
#                 Localidad_inegi                         KEY_inegi_municipio
# 1479                 Teloloapan                         guerrero-teloloapan
# 1480                 Teloloapan                         guerrero-teloloapan
# 1481                  Tecoanapa                          guerrero-tecoanapa
# 1482                 Teloloapan                         guerrero-teloloapan
# 1483                 Teloloapan                         guerrero-teloloapan
# 1484                 Teloloapan                         guerrero-teloloapan
# 1485                  Tecoanapa                          guerrero-tecoanapa
# 1486                 Teloloapan                         guerrero-teloloapan
# 1487                 Teloloapan                         guerrero-teloloapan
# 1488       San Miguel Totolapan               guerrero-san miguel totolapan
# 1489                  Tecoanapa                          guerrero-tecoanapa
# 1490       San Miguel Totolapan               guerrero-san miguel totolapan
# 1491       San Miguel Totolapan               guerrero-san miguel totolapan
# 1492                 Teloloapan                         guerrero-teloloapan
# 1493    Coahuayutla de Guerrero  guerrero-coahuayutla de jose maria izazaga
# 1494                  Tecoanapa                          guerrero-tecoanapa
# 1495                 Teloloapan                         guerrero-teloloapan
# 1496                 Teloloapan                         guerrero-teloloapan
# 1497                 Teloloapan                         guerrero-teloloapan
# 1498                 Teloloapan                         guerrero-teloloapan
# 1499                 Teloloapan                         guerrero-teloloapan
# 1500                     Apango                 guerrero-martir de cuilapan
# 1502                 Teloloapan                         guerrero-teloloapan
# 1503       San Miguel Totolapan               guerrero-san miguel totolapan
# 1504                  Tecoanapa                          guerrero-tecoanapa
# 1505                  Tecoanapa                          guerrero-tecoanapa
# 1507                 Teloloapan                         guerrero-teloloapan
# 1508                 Teloloapan                         guerrero-teloloapan
# 1509                 Teloloapan                         guerrero-teloloapan
# 1510                 Teloloapan                         guerrero-teloloapan
# 1511                 Teloloapan                         guerrero-teloloapan
# 1512       San Miguel Totolapan               guerrero-san miguel totolapan
# 1513       San Miguel Totolapan               guerrero-san miguel totolapan
# 1514                 Teloloapan                         guerrero-teloloapan
# 1515                 Teloloapan                         guerrero-teloloapan
# 1516       San Miguel Totolapan               guerrero-san miguel totolapan
# 1517                  Tecoanapa                          guerrero-tecoanapa
# 1518                 Teloloapan                         guerrero-teloloapan
# 1519                  Tecoanapa                          guerrero-tecoanapa
# 1520                  Tecoanapa                          guerrero-tecoanapa
# 1521                  Tecoanapa                          guerrero-tecoanapa
# 1522                  Tecoanapa                          guerrero-tecoanapa
# 1523       San Miguel Totolapan               guerrero-san miguel totolapan
# 1524       San Miguel Totolapan               guerrero-san miguel totolapan
# 1526       San Miguel Totolapan               guerrero-san miguel totolapan
# 1527       Ayutla de los Libres               guerrero-ayutla de los libres
# 1528          Atoyac de Álvarez                  guerrero-atoyac de alvarez
# 1529                  Tecoanapa                          guerrero-tecoanapa
# 1530            Tierra Colorada                   guerrero-juan r. escudero
# 275401                  Ninguno                          guerrero-tlalchapa
#
# [50 rows x 26 columns]

# %%
listado_beneficiarios_parte_II_localidades.columns
# Out:
# Index(['BENEFICIARIO', 'ZONA', 'ENTIDAD', 'MUNICIPIO', 'LOCALIDAD', 'PRODUCTO',
#        'FECHA', 'MONTO FEDERAL', 'CICLO AGRÍCOLA', 'ENTIDAD_c_benef',
#        'MUNICIPIO_c_benef', 'LOCALIDAD_c_benef', 'KEY_benef_loc_benef',
#        'MUNICIPIO_Clean', 'LOCALIDAD_Clean', 'Municipio-loc-KEY',
#        'KEY_benef_loc_inegi', 'match_score', 'KEY_inegi_localidad', 'CVE_ENT',
#        'Entidad_inegi', 'CVE_MUN', 'Municipio_inegi', 'CVE_LOC',
#        'Localidad_inegi', 'KEY_inegi_municipio'],
#       dtype='object')

# %%
listado_beneficiarios_parte_II_localidades.drop(columns=['ENTIDAD', 'MUNICIPIO', 'LOCALIDAD', 'ENTIDAD_c_benef',
       'MUNICIPIO_c_benef', 'LOCALIDAD_c_benef', 'KEY_benef_loc_benef',
       'MUNICIPIO_Clean', 'LOCALIDAD_Clean', 'Municipio-loc-KEY',
       'KEY_benef_loc_inegi', 'match_score', 'KEY_inegi_localidad',
       'KEY_inegi_municipio'], inplace=True)

# %%
listado_beneficiarios_parte_II_localidades.columns
# Out:
# Index(['BENEFICIARIO', 'ZONA', 'PRODUCTO', 'FECHA', 'MONTO FEDERAL',
#        'CICLO AGRÍCOLA', 'CVE_ENT', 'Entidad_inegi', 'CVE_MUN',
#        'Municipio_inegi', 'CVE_LOC', 'Localidad_inegi'],
#       dtype='object')

# %%
listado_beneficiarios_parte_II_localidades.rename(columns={'BENEFICIARIO': 'Nombre del beneficiario',
                                                           'ZONA': 'Zona del país',
                                                           'CVE_ENT': 'Clave de entidad',
                                                            'Entidad_inegi': 'Entidad federativa',
                                                            'CVE_MUN': 'Clave de municipio',
                                                            'Municipio_inegi': 'Municipio',                                                           
                                                            'CVE_LOC': 'Clave de localidad',
                                                            'Localidad_inegi': 'Localidad',
                                                            'PRODUCTO': 'Producto cultivado',
                                                            'FECHA': 'Fecha de entrega del beneficio',
                                                            'MONTO FEDERAL': 'Monto entregado',
                                                            'CICLO AGRÍCOLA': 'Ciclo agrícola'}, inplace=True)

# %%
listado_beneficiarios_parte_II_localidades
# Out:
#                Nombre del beneficiario Zona del país     Producto cultivado  \
# 0          HERNANDEZ MORALES BERNARDO       NACIONAL  Cultivo de maíz grano
# 1       GUZMAN VARGAS CELEDONIA JUANA       NACIONAL  Cultivo de maíz grano
# 2            REFUGIO RIVERA VALENTINA       NACIONAL  Cultivo de maíz grano
# 3                LOPEZ GUZMAN AGAPITO       NACIONAL  Cultivo de maíz grano
# 4              SALINAS SALGADO FELIPE       NACIONAL  Cultivo de maíz grano
# ...                                ...           ...                    ...
# 276501        CASTILLO CUEVAS AMANCIO    CENTRO PAÍS  Cultivo de maíz grano
# 276502       RUEDA SECUNDINO ANACLETO    CENTRO PAÍS  Cultivo de maíz grano
# 276503          ARMENTA VILLEGAS LUIS    CENTRO PAÍS  Cultivo de maíz grano
# 276504         BELLO JIMENEZ GREGORIA    CENTRO PAÍS  Cultivo de maíz grano
# 276505     CASIMIRO MARTINEZ ELIBORIA    CENTRO PAÍS  Cultivo de maíz grano
#
#        Fecha de entrega del beneficio  Monto entregado Ciclo agrícola  \
# 0                                2019          2191.55         PV2019
# 1                                2019          6813.65         PV2019
# 2                                2019          6813.65         PV2019
# 3                                2019          4383.10         PV2019
# 4                                2019          2430.55         PV2019
# ...                               ...              ...            ...
# 276501                     27/06/2019          2430.55         PV2019
# 276502                     27/06/2019          2430.55         PV2019
# 276503                     06/07/2019          2430.55         PV2019
# 276504                     15/07/2019          6574.65         PV2019
# 276505                     27/06/2019          2430.55         PV2019
#
#        Clave de entidad Entidad federativa Clave de municipio  \
# 0                    21             Puebla                145
# 1                    12           Guerrero                041
# 2                    12           Guerrero                041
# 3                    12           Guerrero                071
# 4                    12           Guerrero                058
# ...                 ...                ...                ...
# 276501               12           Guerrero                055
# 276502               12           Guerrero                055
# 276503               12           Guerrero                017
# 276504               12           Guerrero                010
# 276505               12           Guerrero                055
#
#                        Municipio Clave de localidad       Localidad
# 0       San Sebastián Tlacotepec               0064         Xonoátl
# 1                   Malinaltepec               0001    Malinaltepec
# 2                   Malinaltepec               0001    Malinaltepec
# 3                 Xochistlahuaca               0001  Xochistlahuaca
# 4                     Teloloapan               0001      Teloloapan
# ...                          ...                ...             ...
# 276501          Taxco de Alarcón               0026         Paintla
# 276502          Taxco de Alarcón               0026         Paintla
# 276503                    Cocula               0001          Cocula
# 276504                  Atlixtac               0042    Xalpitzáhuac
# 276505          Taxco de Alarcón               0026         Paintla
#
# [276506 rows x 12 columns]

# %%
listado_beneficiarios_parte_II_localidades.to_csv('../../data/listados_completos/listado_beneficiarios_2019_localidades.csv', index=False)
